# %%
"""
Created on August 31 2022
    
@author: JJ
"""
# Out:
# '\nCreated on August 31 2022\n\n@author: JJ\n'

# %%
import os, re, sys
os.environ["CUDA_VISIBLE_DEVICES"]="0"
import numpy as np
import pandas as pd
from math import log
import random
import scipy.io
import tensorflow as tf
import csv

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
from tensorflow.keras.optimizers import *
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.constraints import MaxNorm
from tensorflow.keras.regularizers import (
    l2, 
    l1, 
    l1_l2
)
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras import (
    activations, 
    initializers, 
    regularizers, 
    constraints
)

# %%
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  # Restrict TensorFlow to only allocate 1GB of memory on the first GPU
  try:
    tf.config.set_logical_device_configuration(
        gpus[0],
        [tf.config.LogicalDeviceConfiguration(memory_limit=6400)])
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Virtual devices must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
#import from python files
from model import build_model

# %%
# in a well-defined initial state.
random.seed(1337)
np.random.seed(1337)
tf.random.set_seed(1337)

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
from tensorflow.keras.callbacks import (
    ModelCheckpoint, 
    EarlyStopping
)
from sklearn.metrics import (
    roc_curve,
    auc,
    roc_auc_score,
    average_precision_score,
    precision_recall_curve,
)

# %%
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.utils import resample, shuffle
from sklearn.feature_selection import (
    SelectKBest,
    chi2
)
from collections import defaultdict

# %%
all_pep, all_mhc, all_target = np.load('all_pep.npy'), np.load('all_mhc.npy'), np.load('all_target.npy')

# %%
from dataclasses import replace


def balanced_sampling(pep, mhc, target):
    pos = np.where(target==1)
    neg = np.where(target==0)

    pep_pos, mhc_pos, target_pos = pep[pos], mhc[pos], target[pos]
    pep_neg, mhc_neg, target_neg = pep[neg], mhc[neg], target[neg]

    pep_pos, mhc_pos, target_pos = resample(pep_pos, mhc_pos, target_pos, n_samples= len(target_pos), replace = False)
    pep_neg, mhc_neg, target_neg = resample(pep_neg, mhc_neg, target_neg, n_samples= len(target_pos), replace = False)


    pep = np.concatenate([pep_pos, pep_neg])
    mhc = np.concatenate([mhc_pos, mhc_neg])
    target = np.concatenate([target_pos, target_neg])

    pep, mhc, target = shuffle(pep, mhc, target)
    return pep, mhc, target

# %%
train_pep, test_pep, train_mhc, test_mhc, train_target, test_target = train_test_split(all_pep, all_mhc, all_target, test_size = 0.2, stratify= all_target)

# %%
print(train_pep.shape)
print(test_pep.shape)
# Out:
# (756875, 30, 20)
# (189219, 30, 20)

# %%
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=1337)    
allprobas_=np.array([]) 
all_labels=np.array([])

# %%
folder = 'model/Ensemble/'

# %%
es = EarlyStopping(monitor = 'val_accuracy', mode = 'max', verbose = 1, patience = 5)

# %%
import gc
class MyCustomCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs = None):
        gc.collect()
        tf.keras.backend.clear_session()

# %%
for u in range(10):
        pep_bal, mhc_bal, target_bal = balanced_sampling(train_pep, train_mhc, train_target)
        folder = 'model/Ensemble/CV_'+str(u)+'/'
        for i, (train, test) in enumerate(kfold.split(train_pep, train_target)):
                training_pep = train_pep[train]
                training_mhc = train_mhc[train]
                training_target = train_target[train]
                
                validation_pep = train_pep[test]
                validation_mhc = train_mhc[test]
                validation_target = train_target[test]

                mc = ModelCheckpoint(folder+'model_' +str(i)+'.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

                if i == 0: 
                        model = build_model(training_pep, training_mhc)
                #model.summary()

                model.fit([training_pep,training_mhc], 
                        training_target,
                        batch_size=512,
                        epochs = 100,
                        shuffle=True,
                        callbacks=[es, mc],
                        validation_data=([validation_pep,validation_mhc], validation_target),
                        verbose=1)  
                        
                del model
                gc.collect()
                tf.keras.backend.clear_session()

        gc.collect()
        tf.keras.backend.clear_session()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# peptide (InputLayer)            [(None, 30, 20)]     0
# __________________________________________________________________________________________________
# mhc (InputLayer)                [(None, 34, 20)]     0
# __________________________________________________________________________________________________
# conv1_pep (Conv1D)              (None, 30, 128)      7808        peptide[0][0]
# __________________________________________________________________________________________________
# conv1_mhc (Conv1D)              (None, 34, 128)      7808        mhc[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 15, 128)      0           conv1_pep[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 17, 128)      0           conv1_mhc[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 15, 128)      0           max_pooling1d[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 17, 128)      0           max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1920)         0           dropout[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2176)         0           dropout_2[0][0]
# __________________________________________________________________________________________________
# attention (Attention)           (None, 143)          33281       dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1920)         0           flatten[0][0]
# __________________________________________________________________________________________________
# attention_1 (Attention)         (None, 145)          33281       dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 2176)         0           flatten_1[0][0]
# __________________________________________________________________________________________________
# attention_flatten (attention_fl (None, 128)          0           attention[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            1921        dropout_1[0][0]
# __________________________________________________________________________________________________
# attention_flatten_1 (attention_ (None, 128)          0           attention_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            2177        dropout_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 129)          0           attention_flatten[0][0]
#                                                                  dense[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 129)          0           attention_flatten_1[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            130         concatenate[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            130         concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 2)            0           dense_1[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            3           concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 1)            0           dense_4[0][0]
# ==================================================================================================
# Total params: 86,539
# Trainable params: 86,539
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/100
# 1183/1183 [==============================] - 22s 14ms/step - loss: 0.2369 - accuracy: 0.9107 - auc: 0.8382 - val_loss: 0.2104 - val_accuracy: 0.9142 - val_auc: 0.8881
#
# Epoch 00001: val_accuracy improved from -inf to 0.91422, saving model to model/Ensemble/CV_0\model_0.h5
# Epoch 2/100
# 1183/1183 [==============================] - 15s 12ms/step - loss: 0.2145 - accuracy: 0.9143 - auc: 0.8785 - val_loss: 0.2038 - val_accuracy: 0.9171 - val_auc: 0.8945
#
# Epoch 00002: val_accuracy improved from 0.91422 to 0.91709, saving model to model/Ensemble/CV_0\model_0.h5
# Epoch 3/100
# 1183/1183 [==============================] - 15s 12ms/step - loss: 0.2105 - accuracy: 0.9154 - auc: 0.8843 - val_loss: 0.2017 - val_accuracy: 0.9169 - val_auc: 0.8979
#
# Epoch 00003: val_accuracy did not improve from 0.91709
# Epoch 4/100
# 1183/1183 [==============================] - 15s 12ms/step - loss: 0.2084 - accuracy: 0.9158 - auc: 0.8873 - val_loss: 0.1993 - val_accuracy: 0.9188 - val_auc: 0.9005
#
# Epoch 00004: val_accuracy improved from 0.91709 to 0.91876, saving model to model/Ensemble/CV_0\model_0.h5
# Epoch 5/100
# 1183/1183 [==============================] - 15s 12ms/step - loss: 0.2070 - accuracy: 0.9162 - auc: 0.8892 - val_loss: 0.1988 - val_accuracy: 0.9177 - val_auc: 0.9018
#
# Epoch 00005: val_accuracy did not improve from 0.91876
# Epoch 6/100
# 1183/1183 [==============================] - 15s 12ms/step - loss: 0.2055 - accuracy: 0.9167 - auc: 0.8913 - val_loss: 0.1983 - val_accuracy: 0.9180 - val_auc: 0.9022
#
# Epoch 00006: val_accuracy did not improve from 0.91876
# Epoch 7/100
# 1183/1183 [==============================] - 15s 12ms/step - loss: 0.2049 - accuracy: 0.9170 - auc: 0.8919 - val_loss: 0.1974 - val_accuracy: 0.9186 - val_auc: 0.9028
#
# Epoch 00007: val_accuracy did not improve from 0.91876
# Epoch 8/100
# 1183/1183 [==============================] - 15s 12ms/step - loss: 0.2042 - accuracy: 0.9171 - auc: 0.8928 - val_loss: 0.1994 - val_accuracy: 0.9170 - val_auc: 0.9030
#
# Epoch 00008: val_accuracy did not improve from 0.91876
# Epoch 9/100
# 1183/1183 [==============================] - 15s 12ms/step - loss: 0.2037 - accuracy: 0.9174 - auc: 0.8936 - val_loss: 0.1962 - val_accuracy: 0.9188 - val_auc: 0.9044
#
# Epoch 00009: val_accuracy did not improve from 0.91876
# Epoch 00009: early stopping
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# peptide (InputLayer)            [(None, 30, 20)]     0
# __________________________________________________________________________________________________
# mhc (InputLayer)                [(None, 34, 20)]     0
# __________________________________________________________________________________________________
# conv1_pep (Conv1D)              (None, 30, 128)      7808        peptide[0][0]
# __________________________________________________________________________________________________
# conv1_mhc (Conv1D)              (None, 34, 128)      7808        mhc[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 15, 128)      0           conv1_pep[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 17, 128)      0           conv1_mhc[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 15, 128)      0           max_pooling1d[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 17, 128)      0           max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1920)         0           dropout[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2176)         0           dropout_2[0][0]
# __________________________________________________________________________________________________
# attention (Attention)           (None, 143)          33281       dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1920)         0           flatten[0][0]
# __________________________________________________________________________________________________
# attention_1 (Attention)         (None, 145)          33281       dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 2176)         0           flatten_1[0][0]
# __________________________________________________________________________________________________
# attention_flatten (attention_fl (None, 128)          0           attention[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            1921        dropout_1[0][0]
# __________________________________________________________________________________________________
# attention_flatten_1 (attention_ (None, 128)          0           attention_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            2177        dropout_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 129)          0           attention_flatten[0][0]
#                                                                  dense[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 129)          0           attention_flatten_1[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            130         concatenate[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            130         concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 2)            0           dense_1[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            3           concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 1)            0           dense_4[0][0]
# ==================================================================================================
# Total params: 86,539
# Trainable params: 86,539
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/100
# 1183/1183 [==============================] - 17s 13ms/step - loss: 0.2406 - accuracy: 0.9108 - auc: 0.8304 - val_loss: 0.2132 - val_accuracy: 0.9143 - val_auc: 0.8814
#
# Epoch 00001: val_accuracy improved from -inf to 0.91433, saving model to model/Ensemble/CV_0\model_1.h5
# Epoch 2/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2155 - accuracy: 0.9137 - auc: 0.8771 - val_loss: 0.2050 - val_accuracy: 0.9163 - val_auc: 0.8934
#
# Epoch 00002: val_accuracy improved from 0.91433 to 0.91628, saving model to model/Ensemble/CV_0\model_1.h5
# Epoch 3/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2113 - accuracy: 0.9147 - auc: 0.8832 - val_loss: 0.2026 - val_accuracy: 0.9164 - val_auc: 0.8971
#
# Epoch 00003: val_accuracy improved from 0.91628 to 0.91639, saving model to model/Ensemble/CV_0\model_1.h5
# Epoch 4/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2087 - accuracy: 0.9153 - auc: 0.8869 - val_loss: 0.2009 - val_accuracy: 0.9169 - val_auc: 0.8988
#
# Epoch 00004: val_accuracy improved from 0.91639 to 0.91686, saving model to model/Ensemble/CV_0\model_1.h5
# Epoch 5/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2075 - accuracy: 0.9157 - auc: 0.8886 - val_loss: 0.2008 - val_accuracy: 0.9167 - val_auc: 0.8996
#
# Epoch 00005: val_accuracy did not improve from 0.91686
# Epoch 6/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2066 - accuracy: 0.9162 - auc: 0.8895 - val_loss: 0.1985 - val_accuracy: 0.9183 - val_auc: 0.9014
#
# Epoch 00006: val_accuracy improved from 0.91686 to 0.91826, saving model to model/Ensemble/CV_0\model_1.h5
# Epoch 7/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2056 - accuracy: 0.9165 - auc: 0.8910 - val_loss: 0.1980 - val_accuracy: 0.9185 - val_auc: 0.9018
#
# Epoch 00007: val_accuracy improved from 0.91826 to 0.91847, saving model to model/Ensemble/CV_0\model_1.h5
# Epoch 8/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2056 - accuracy: 0.9163 - auc: 0.8912 - val_loss: 0.1987 - val_accuracy: 0.9181 - val_auc: 0.9016
#
# Epoch 00008: val_accuracy did not improve from 0.91847
# Epoch 9/100
# 1183/1183 [==============================] - 15s 12ms/step - loss: 0.2049 - accuracy: 0.9167 - auc: 0.8920 - val_loss: 0.1978 - val_accuracy: 0.9186 - val_auc: 0.9020
#
# Epoch 00009: val_accuracy improved from 0.91847 to 0.91863, saving model to model/Ensemble/CV_0\model_1.h5
# Epoch 10/100
# 1183/1183 [==============================] - 15s 12ms/step - loss: 0.2046 - accuracy: 0.9169 - auc: 0.8923 - val_loss: 0.1969 - val_accuracy: 0.9199 - val_auc: 0.9033
#
# Epoch 00010: val_accuracy improved from 0.91863 to 0.91994, saving model to model/Ensemble/CV_0\model_1.h5
# Epoch 11/100
# 1183/1183 [==============================] - 15s 12ms/step - loss: 0.2039 - accuracy: 0.9173 - auc: 0.8933 - val_loss: 0.1965 - val_accuracy: 0.9196 - val_auc: 0.9037
#
# Epoch 00011: val_accuracy did not improve from 0.91994
# Epoch 12/100
# 1183/1183 [==============================] - 15s 12ms/step - loss: 0.2040 - accuracy: 0.9166 - auc: 0.8933 - val_loss: 0.1962 - val_accuracy: 0.9193 - val_auc: 0.9038
#
# Epoch 00012: val_accuracy did not improve from 0.91994
# Epoch 13/100
# 1183/1183 [==============================] - 15s 12ms/step - loss: 0.2035 - accuracy: 0.9171 - auc: 0.8940 - val_loss: 0.1958 - val_accuracy: 0.9194 - val_auc: 0.9046
#
# Epoch 00013: val_accuracy did not improve from 0.91994
# Epoch 14/100
# 1183/1183 [==============================] - 15s 12ms/step - loss: 0.2028 - accuracy: 0.9173 - auc: 0.8946 - val_loss: 0.1954 - val_accuracy: 0.9196 - val_auc: 0.9048
#
# Epoch 00014: val_accuracy did not improve from 0.91994
# Epoch 15/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2031 - accuracy: 0.9171 - auc: 0.8944 - val_loss: 0.1958 - val_accuracy: 0.9192 - val_auc: 0.9046
#
# Epoch 00015: val_accuracy did not improve from 0.91994
# Epoch 00015: early stopping
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# peptide (InputLayer)            [(None, 30, 20)]     0
# __________________________________________________________________________________________________
# mhc (InputLayer)                [(None, 34, 20)]     0
# __________________________________________________________________________________________________
# conv1_pep (Conv1D)              (None, 30, 128)      7808        peptide[0][0]
# __________________________________________________________________________________________________
# conv1_mhc (Conv1D)              (None, 34, 128)      7808        mhc[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 15, 128)      0           conv1_pep[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 17, 128)      0           conv1_mhc[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 15, 128)      0           max_pooling1d[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 17, 128)      0           max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1920)         0           dropout[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2176)         0           dropout_2[0][0]
# __________________________________________________________________________________________________
# attention (Attention)           (None, 143)          33281       dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1920)         0           flatten[0][0]
# __________________________________________________________________________________________________
# attention_1 (Attention)         (None, 145)          33281       dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 2176)         0           flatten_1[0][0]
# __________________________________________________________________________________________________
# attention_flatten (attention_fl (None, 128)          0           attention[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            1921        dropout_1[0][0]
# __________________________________________________________________________________________________
# attention_flatten_1 (attention_ (None, 128)          0           attention_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            2177        dropout_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 129)          0           attention_flatten[0][0]
#                                                                  dense[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 129)          0           attention_flatten_1[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            130         concatenate[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            130         concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 2)            0           dense_1[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            3           concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 1)            0           dense_4[0][0]
# ==================================================================================================
# Total params: 86,539
# Trainable params: 86,539
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/100
# 1183/1183 [==============================] - 17s 13ms/step - loss: 0.2415 - accuracy: 0.9109 - auc: 0.8283 - val_loss: 0.2137 - val_accuracy: 0.9143 - val_auc: 0.8809
#
# Epoch 00001: val_accuracy improved from -inf to 0.91431, saving model to model/Ensemble/CV_0\model_2.h5
# Epoch 2/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2145 - accuracy: 0.9144 - auc: 0.8783 - val_loss: 0.2073 - val_accuracy: 0.9166 - val_auc: 0.8910
#
# Epoch 00002: val_accuracy improved from 0.91431 to 0.91658, saving model to model/Ensemble/CV_0\model_2.h5
# Epoch 3/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2105 - accuracy: 0.9152 - auc: 0.8844 - val_loss: 0.2046 - val_accuracy: 0.9161 - val_auc: 0.8942
#
# Epoch 00003: val_accuracy did not improve from 0.91658
# Epoch 4/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2084 - accuracy: 0.9160 - auc: 0.8873 - val_loss: 0.2027 - val_accuracy: 0.9167 - val_auc: 0.8961
#
# Epoch 00004: val_accuracy improved from 0.91658 to 0.91670, saving model to model/Ensemble/CV_0\model_2.h5
# Epoch 5/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2070 - accuracy: 0.9160 - auc: 0.8892 - val_loss: 0.2009 - val_accuracy: 0.9177 - val_auc: 0.8977
#
# Epoch 00005: val_accuracy improved from 0.91670 to 0.91768, saving model to model/Ensemble/CV_0\model_2.h5
# Epoch 6/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2060 - accuracy: 0.9163 - auc: 0.8906 - val_loss: 0.2006 - val_accuracy: 0.9185 - val_auc: 0.8990
#
# Epoch 00006: val_accuracy improved from 0.91768 to 0.91845, saving model to model/Ensemble/CV_0\model_2.h5
# Epoch 7/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2055 - accuracy: 0.9169 - auc: 0.8912 - val_loss: 0.2004 - val_accuracy: 0.9182 - val_auc: 0.8989
#
# Epoch 00007: val_accuracy did not improve from 0.91845
# Epoch 8/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2046 - accuracy: 0.9169 - auc: 0.8924 - val_loss: 0.1996 - val_accuracy: 0.9182 - val_auc: 0.8997
#
# Epoch 00008: val_accuracy did not improve from 0.91845
# Epoch 9/100
# 1183/1183 [==============================] - 15s 12ms/step - loss: 0.2041 - accuracy: 0.9173 - auc: 0.8932 - val_loss: 0.1988 - val_accuracy: 0.9190 - val_auc: 0.9000
#
# Epoch 00009: val_accuracy improved from 0.91845 to 0.91896, saving model to model/Ensemble/CV_0\model_2.h5
# Epoch 10/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2037 - accuracy: 0.9173 - auc: 0.8935 - val_loss: 0.1985 - val_accuracy: 0.9196 - val_auc: 0.9016
#
# Epoch 00010: val_accuracy improved from 0.91896 to 0.91961, saving model to model/Ensemble/CV_0\model_2.h5
# Epoch 11/100
# 1183/1183 [==============================] - 15s 12ms/step - loss: 0.2034 - accuracy: 0.9172 - auc: 0.8941 - val_loss: 0.1978 - val_accuracy: 0.9190 - val_auc: 0.9017
#
# Epoch 00011: val_accuracy did not improve from 0.91961
# Epoch 12/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2032 - accuracy: 0.9176 - auc: 0.8942 - val_loss: 0.1979 - val_accuracy: 0.9196 - val_auc: 0.9023
#
# Epoch 00012: val_accuracy did not improve from 0.91961
# Epoch 13/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2030 - accuracy: 0.9174 - auc: 0.8944 - val_loss: 0.1980 - val_accuracy: 0.9186 - val_auc: 0.9019
#
# Epoch 00013: val_accuracy did not improve from 0.91961
# Epoch 14/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2026 - accuracy: 0.9177 - auc: 0.8951 - val_loss: 0.1971 - val_accuracy: 0.9191 - val_auc: 0.9026
#
# Epoch 00014: val_accuracy did not improve from 0.91961
# Epoch 15/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2021 - accuracy: 0.9179 - auc: 0.8957 - val_loss: 0.1970 - val_accuracy: 0.9192 - val_auc: 0.9026
#
# Epoch 00015: val_accuracy did not improve from 0.91961
# Epoch 00015: early stopping
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# peptide (InputLayer)            [(None, 30, 20)]     0
# __________________________________________________________________________________________________
# mhc (InputLayer)                [(None, 34, 20)]     0
# __________________________________________________________________________________________________
# conv1_pep (Conv1D)              (None, 30, 128)      7808        peptide[0][0]
# __________________________________________________________________________________________________
# conv1_mhc (Conv1D)              (None, 34, 128)      7808        mhc[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 15, 128)      0           conv1_pep[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 17, 128)      0           conv1_mhc[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 15, 128)      0           max_pooling1d[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 17, 128)      0           max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1920)         0           dropout[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2176)         0           dropout_2[0][0]
# __________________________________________________________________________________________________
# attention (Attention)           (None, 143)          33281       dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1920)         0           flatten[0][0]
# __________________________________________________________________________________________________
# attention_1 (Attention)         (None, 145)          33281       dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 2176)         0           flatten_1[0][0]
# __________________________________________________________________________________________________
# attention_flatten (attention_fl (None, 128)          0           attention[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            1921        dropout_1[0][0]
# __________________________________________________________________________________________________
# attention_flatten_1 (attention_ (None, 128)          0           attention_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            2177        dropout_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 129)          0           attention_flatten[0][0]
#                                                                  dense[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 129)          0           attention_flatten_1[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            130         concatenate[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            130         concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 2)            0           dense_1[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            3           concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 1)            0           dense_4[0][0]
# ==================================================================================================
# Total params: 86,539
# Trainable params: 86,539
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/100
# 1183/1183 [==============================] - 17s 13ms/step - loss: 0.2410 - accuracy: 0.9100 - auc: 0.8297 - val_loss: 0.2128 - val_accuracy: 0.9147 - val_auc: 0.8823
#
# Epoch 00001: val_accuracy improved from -inf to 0.91467, saving model to model/Ensemble/CV_0\model_3.h5
# Epoch 2/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2146 - accuracy: 0.9137 - auc: 0.8783 - val_loss: 0.2055 - val_accuracy: 0.9159 - val_auc: 0.8924
#
# Epoch 00002: val_accuracy improved from 0.91467 to 0.91594, saving model to model/Ensemble/CV_0\model_3.h5
# Epoch 3/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2109 - accuracy: 0.9149 - auc: 0.8839 - val_loss: 0.2037 - val_accuracy: 0.9158 - val_auc: 0.8957
#
# Epoch 00003: val_accuracy did not improve from 0.91594
# Epoch 4/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2085 - accuracy: 0.9156 - auc: 0.8872 - val_loss: 0.2023 - val_accuracy: 0.9166 - val_auc: 0.8970
#
# Epoch 00004: val_accuracy improved from 0.91594 to 0.91662, saving model to model/Ensemble/CV_0\model_3.h5
# Epoch 5/100
# 1183/1183 [==============================] - 15s 12ms/step - loss: 0.2071 - accuracy: 0.9162 - auc: 0.8890 - val_loss: 0.2002 - val_accuracy: 0.9186 - val_auc: 0.8988
#
# Epoch 00005: val_accuracy improved from 0.91662 to 0.91859, saving model to model/Ensemble/CV_0\model_3.h5
# Epoch 6/100
# 1183/1183 [==============================] - 15s 12ms/step - loss: 0.2062 - accuracy: 0.9163 - auc: 0.8903 - val_loss: 0.1998 - val_accuracy: 0.9185 - val_auc: 0.8995
#
# Epoch 00006: val_accuracy did not improve from 0.91859
# Epoch 7/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2053 - accuracy: 0.9164 - auc: 0.8915 - val_loss: 0.1987 - val_accuracy: 0.9186 - val_auc: 0.9007
#
# Epoch 00007: val_accuracy improved from 0.91859 to 0.91865, saving model to model/Ensemble/CV_0\model_3.h5
# Epoch 8/100
# 1183/1183 [==============================] - 15s 12ms/step - loss: 0.2043 - accuracy: 0.9169 - auc: 0.8928 - val_loss: 0.1986 - val_accuracy: 0.9189 - val_auc: 0.9013
#
# Epoch 00008: val_accuracy improved from 0.91865 to 0.91889, saving model to model/Ensemble/CV_0\model_3.h5
# Epoch 9/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2040 - accuracy: 0.9172 - auc: 0.8931 - val_loss: 0.1980 - val_accuracy: 0.9189 - val_auc: 0.9023
#
# Epoch 00009: val_accuracy did not improve from 0.91889
# Epoch 10/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2032 - accuracy: 0.9173 - auc: 0.8943 - val_loss: 0.1982 - val_accuracy: 0.9187 - val_auc: 0.9020
#
# Epoch 00010: val_accuracy did not improve from 0.91889
# Epoch 11/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2028 - accuracy: 0.9173 - auc: 0.8949 - val_loss: 0.1985 - val_accuracy: 0.9173 - val_auc: 0.9028
#
# Epoch 00011: val_accuracy did not improve from 0.91889
# Epoch 12/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2026 - accuracy: 0.9175 - auc: 0.8951 - val_loss: 0.1966 - val_accuracy: 0.9207 - val_auc: 0.9028
#
# Epoch 00012: val_accuracy improved from 0.91889 to 0.92066, saving model to model/Ensemble/CV_0\model_3.h5
# Epoch 13/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2019 - accuracy: 0.9177 - auc: 0.8960 - val_loss: 0.1968 - val_accuracy: 0.9188 - val_auc: 0.9038
#
# Epoch 00013: val_accuracy did not improve from 0.92066
# Epoch 14/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2017 - accuracy: 0.9176 - auc: 0.8963 - val_loss: 0.1962 - val_accuracy: 0.9201 - val_auc: 0.9035
#
# Epoch 00014: val_accuracy did not improve from 0.92066
# Epoch 15/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2012 - accuracy: 0.9179 - auc: 0.8969 - val_loss: 0.1966 - val_accuracy: 0.9196 - val_auc: 0.9038
#
# Epoch 00015: val_accuracy did not improve from 0.92066
# Epoch 16/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2011 - accuracy: 0.9181 - auc: 0.8971 - val_loss: 0.1962 - val_accuracy: 0.9197 - val_auc: 0.9037
#
# Epoch 00016: val_accuracy did not improve from 0.92066
# Epoch 17/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2008 - accuracy: 0.9180 - auc: 0.8973 - val_loss: 0.1958 - val_accuracy: 0.9198 - val_auc: 0.9045
#
# Epoch 00017: val_accuracy did not improve from 0.92066
# Epoch 00017: early stopping
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# peptide (InputLayer)            [(None, 30, 20)]     0
# __________________________________________________________________________________________________
# mhc (InputLayer)                [(None, 34, 20)]     0
# __________________________________________________________________________________________________
# conv1_pep (Conv1D)              (None, 30, 128)      7808        peptide[0][0]
# __________________________________________________________________________________________________
# conv1_mhc (Conv1D)              (None, 34, 128)      7808        mhc[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 15, 128)      0           conv1_pep[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 17, 128)      0           conv1_mhc[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 15, 128)      0           max_pooling1d[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 17, 128)      0           max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1920)         0           dropout[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2176)         0           dropout_2[0][0]
# __________________________________________________________________________________________________
# attention (Attention)           (None, 143)          33281       dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1920)         0           flatten[0][0]
# __________________________________________________________________________________________________
# attention_1 (Attention)         (None, 145)          33281       dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 2176)         0           flatten_1[0][0]
# __________________________________________________________________________________________________
# attention_flatten (attention_fl (None, 128)          0           attention[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            1921        dropout_1[0][0]
# __________________________________________________________________________________________________
# attention_flatten_1 (attention_ (None, 128)          0           attention_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            2177        dropout_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 129)          0           attention_flatten[0][0]
#                                                                  dense[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 129)          0           attention_flatten_1[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            130         concatenate[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            130         concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 2)            0           dense_1[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            3           concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 1)            0           dense_4[0][0]
# ==================================================================================================
# Total params: 86,539
# Trainable params: 86,539
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/100
# 1183/1183 [==============================] - 17s 13ms/step - loss: 0.2412 - accuracy: 0.9105 - auc: 0.8288 - val_loss: 0.2116 - val_accuracy: 0.9137 - val_auc: 0.8866
#
# Epoch 00001: val_accuracy improved from -inf to 0.91374, saving model to model/Ensemble/CV_0\model_4.h5
# Epoch 2/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2157 - accuracy: 0.9139 - auc: 0.8764 - val_loss: 0.2034 - val_accuracy: 0.9171 - val_auc: 0.8954
#
# Epoch 00002: val_accuracy improved from 0.91374 to 0.91711, saving model to model/Ensemble/CV_0\model_4.h5
# Epoch 3/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2116 - accuracy: 0.9150 - auc: 0.8827 - val_loss: 0.2006 - val_accuracy: 0.9174 - val_auc: 0.8991
#
# Epoch 00003: val_accuracy improved from 0.91711 to 0.91744, saving model to model/Ensemble/CV_0\model_4.h5
# Epoch 4/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2089 - accuracy: 0.9159 - auc: 0.8865 - val_loss: 0.2015 - val_accuracy: 0.9159 - val_auc: 0.9002
#
# Epoch 00004: val_accuracy did not improve from 0.91744
# Epoch 5/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2077 - accuracy: 0.9160 - auc: 0.8882 - val_loss: 0.1989 - val_accuracy: 0.9177 - val_auc: 0.9012
#
# Epoch 00005: val_accuracy improved from 0.91744 to 0.91771, saving model to model/Ensemble/CV_0\model_4.h5
# Epoch 6/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2068 - accuracy: 0.9166 - auc: 0.8893 - val_loss: 0.1975 - val_accuracy: 0.9181 - val_auc: 0.9037
#
# Epoch 00006: val_accuracy improved from 0.91771 to 0.91808, saving model to model/Ensemble/CV_0\model_4.h5
# Epoch 7/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2059 - accuracy: 0.9163 - auc: 0.8907 - val_loss: 0.1968 - val_accuracy: 0.9188 - val_auc: 0.9045
#
# Epoch 00007: val_accuracy improved from 0.91808 to 0.91877, saving model to model/Ensemble/CV_0\model_4.h5
# Epoch 8/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2055 - accuracy: 0.9166 - auc: 0.8914 - val_loss: 0.1962 - val_accuracy: 0.9189 - val_auc: 0.9046
#
# Epoch 00008: val_accuracy improved from 0.91877 to 0.91886, saving model to model/Ensemble/CV_0\model_4.h5
# Epoch 9/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2044 - accuracy: 0.9174 - auc: 0.8926 - val_loss: 0.1957 - val_accuracy: 0.9190 - val_auc: 0.9050
#
# Epoch 00009: val_accuracy improved from 0.91886 to 0.91904, saving model to model/Ensemble/CV_0\model_4.h5
# Epoch 10/100
# 1183/1183 [==============================] - 15s 12ms/step - loss: 0.2041 - accuracy: 0.9172 - auc: 0.8930 - val_loss: 0.1950 - val_accuracy: 0.9198 - val_auc: 0.9055
#
# Epoch 00010: val_accuracy improved from 0.91904 to 0.91980, saving model to model/Ensemble/CV_0\model_4.h5
# Epoch 11/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2035 - accuracy: 0.9174 - auc: 0.8938 - val_loss: 0.1950 - val_accuracy: 0.9190 - val_auc: 0.9058
#
# Epoch 00011: val_accuracy did not improve from 0.91980
# Epoch 12/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2030 - accuracy: 0.9176 - auc: 0.8944 - val_loss: 0.1953 - val_accuracy: 0.9198 - val_auc: 0.9067
#
# Epoch 00012: val_accuracy improved from 0.91980 to 0.91982, saving model to model/Ensemble/CV_0\model_4.h5
# Epoch 13/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2029 - accuracy: 0.9176 - auc: 0.8947 - val_loss: 0.1955 - val_accuracy: 0.9185 - val_auc: 0.9061
#
# Epoch 00013: val_accuracy did not improve from 0.91982
# Epoch 14/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2022 - accuracy: 0.9178 - auc: 0.8956 - val_loss: 0.1952 - val_accuracy: 0.9186 - val_auc: 0.9066
#
# Epoch 00014: val_accuracy did not improve from 0.91982
# Epoch 15/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2017 - accuracy: 0.9178 - auc: 0.8961 - val_loss: 0.1935 - val_accuracy: 0.9198 - val_auc: 0.9076
#
# Epoch 00015: val_accuracy did not improve from 0.91982
# Epoch 16/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2014 - accuracy: 0.9180 - auc: 0.8966 - val_loss: 0.1950 - val_accuracy: 0.9191 - val_auc: 0.9068
#
# Epoch 00016: val_accuracy did not improve from 0.91982
# Epoch 17/100
# 1183/1183 [==============================] - 15s 13ms/step - loss: 0.2014 - accuracy: 0.9183 - auc: 0.8964 - val_loss: 0.1945 - val_accuracy: 0.9188 - val_auc: 0.9078
#
# Epoch 00017: val_accuracy did not improve from 0.91982
# Epoch 00017: early stopping
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# Epoch 3/100
# 1183/1183 [==============================] - 14s 12ms/step - loss: 0.2123 - accuracy: 0.9145 - auc: 0.8820 - val_loss: 0.2055 - val_accuracy: 0.9155 - val_auc: 0.8941
#
# Epoch 00003: val_accuracy did not improve from 0.91615
# Epoch 4/100
# 1183/1183 [==============================] - 14s 12ms/step - loss: 0.2094 - accuracy: 0.9152 - auc: 0.8861 - val_loss: 0.2025 - val_accuracy: 0.9169 - val_auc: 0.8964
#
# Epoch 00004: val_accuracy improved from 0.91615 to 0.91692, saving model to model/Ensemble/CV_9\model_3.h5
# Epoch 5/100
# 1183/1183 [==============================] - 14s 12ms/step - loss: 0.2083 - accuracy: 0.9157 - auc: 0.8876 - val_loss: 0.2009 - val_accuracy: 0.9183 - val_auc: 0.8978
#
# Epoch 00005: val_accuracy improved from 0.91692 to 0.91834, saving model to model/Ensemble/CV_9\model_3.h5
# Epoch 6/100
# 1183/1183 [==============================] - 15s 12ms/step - loss: 0.2065 - accuracy: 0.9161 - auc: 0.8901 - val_loss: 0.1997 - val_accuracy: 0.9187 - val_auc: 0.8991
#
# Epoch 00006: val_accuracy improved from 0.91834 to 0.91869, saving model to model/Ensemble/CV_9\model_3.h5
# Epoch 7/100
# 1183/1183 [==============================] - 14s 12ms/step - loss: 0.2059 - accuracy: 0.9163 - auc: 0.8910 - val_loss: 0.2003 - val_accuracy: 0.9177 - val_auc: 0.8999
#
# Epoch 00007: val_accuracy did not improve from 0.91869
# Epoch 8/100
# 1183/1183 [==============================] - 14s 12ms/step - loss: 0.2051 - accuracy: 0.9169 - auc: 0.8918 - val_loss: 0.1988 - val_accuracy: 0.9192 - val_auc: 0.9007
#
# Epoch 00008: val_accuracy improved from 0.91869 to 0.91919, saving model to model/Ensemble/CV_9\model_3.h5
# Epoch 9/100
# 1183/1183 [==============================] - 14s 12ms/step - loss: 0.2048 - accuracy: 0.9168 - auc: 0.8923 - val_loss: 0.1982 - val_accuracy: 0.9191 - val_auc: 0.9015
#
# Epoch 00009: val_accuracy did not improve from 0.91919
# Epoch 10/100
# 1183/1183 [==============================] - 14s 12ms/step - loss: 0.2043 - accuracy: 0.9170 - auc: 0.8929 - val_loss: 0.1983 - val_accuracy: 0.9185 - val_auc: 0.9015
#
# Epoch 00010: val_accuracy did not improve from 0.91919
# Epoch 11/100
# 1183/1183 [==============================] - 14s 12ms/step - loss: 0.2037 - accuracy: 0.9170 - auc: 0.8939 - val_loss: 0.1994 - val_accuracy: 0.9177 - val_auc: 0.9018
#
# Epoch 00011: val_accuracy did not improve from 0.91919
# Epoch 12/100
# 1183/1183 [==============================] - 14s 12ms/step - loss: 0.2029 - accuracy: 0.9172 - auc: 0.8947 - val_loss: 0.1970 - val_accuracy: 0.9199 - val_auc: 0.9022
#
# Epoch 00012: val_accuracy improved from 0.91919 to 0.91987, saving model to model/Ensemble/CV_9\model_3.h5
# Epoch 13/100
# 1183/1183 [==============================] - 14s 12ms/step - loss: 0.2027 - accuracy: 0.9173 - auc: 0.8950 - val_loss: 0.1968 - val_accuracy: 0.9196 - val_auc: 0.9031
#
# Epoch 00013: val_accuracy did not improve from 0.91987
# Epoch 14/100
# 1183/1183 [==============================] - 14s 12ms/step - loss: 0.2024 - accuracy: 0.9175 - auc: 0.8955 - val_loss: 0.1967 - val_accuracy: 0.9197 - val_auc: 0.9031
#
# Epoch 00014: val_accuracy did not improve from 0.91987
# Epoch 15/100
# 1183/1183 [==============================] - 14s 12ms/step - loss: 0.2019 - accuracy: 0.9177 - auc: 0.8961 - val_loss: 0.1973 - val_accuracy: 0.9189 - val_auc: 0.9030
#
# Epoch 00015: val_accuracy did not improve from 0.91987
# Epoch 16/100
# 1183/1183 [==============================] - 14s 12ms/step - loss: 0.2014 - accuracy: 0.9178 - auc: 0.8967 - val_loss: 0.1966 - val_accuracy: 0.9195 - val_auc: 0.9031
#
# Epoch 00016: val_accuracy did not improve from 0.91987
# Epoch 17/100
# 1183/1183 [==============================] - 14s 12ms/step - loss: 0.2011 - accuracy: 0.9179 - auc: 0.8971 - val_loss: 0.1965 - val_accuracy: 0.9198 - val_auc: 0.9035
#
# Epoch 00017: val_accuracy did not improve from 0.91987
# Epoch 00017: early stopping
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# peptide (InputLayer)            [(None, 30, 20)]     0
# __________________________________________________________________________________________________
# mhc (InputLayer)                [(None, 34, 20)]     0
# __________________________________________________________________________________________________
# conv1_pep (Conv1D)              (None, 30, 128)      7808        peptide[0][0]
# __________________________________________________________________________________________________
# conv1_mhc (Conv1D)              (None, 34, 128)      7808        mhc[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 15, 128)      0           conv1_pep[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 17, 128)      0           conv1_mhc[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 15, 128)      0           max_pooling1d[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 17, 128)      0           max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1920)         0           dropout[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2176)         0           dropout_2[0][0]
# __________________________________________________________________________________________________
# attention (Attention)           (None, 143)          33281       dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1920)         0           flatten[0][0]
# __________________________________________________________________________________________________
# attention_1 (Attention)         (None, 145)          33281       dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 2176)         0           flatten_1[0][0]
# __________________________________________________________________________________________________
# attention_flatten (attention_fl (None, 128)          0           attention[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            1921        dropout_1[0][0]
# __________________________________________________________________________________________________
# attention_flatten_1 (attention_ (None, 128)          0           attention_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            2177        dropout_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 129)          0           attention_flatten[0][0]
#                                                                  dense[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 129)          0           attention_flatten_1[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            130         concatenate[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            130         concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 2)            0           dense_1[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            3           concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 1)            0           dense_4[0][0]
# ==================================================================================================
# Total params: 86,539
# Trainable params: 86,539
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/100
# 1183/1183 [==============================] - 16s 13ms/step - loss: 0.2405 - accuracy: 0.9096 - auc: 0.8316 - val_loss: 0.2121 - val_accuracy: 0.9133 - val_auc: 0.8874
#
# Epoch 00001: val_accuracy improved from -inf to 0.91333, saving model to model/Ensemble/CV_9\model_4.h5
# Epoch 2/100
# 1183/1183 [==============================] - 15s 12ms/step - loss: 0.2145 - accuracy: 0.9142 - auc: 0.8785 - val_loss: 0.2030 - val_accuracy: 0.9172 - val_auc: 0.8959
#
# Epoch 00002: val_accuracy improved from 0.91333 to 0.91721, saving model to model/Ensemble/CV_9\model_4.h5
# Epoch 3/100
# 1183/1183 [==============================] - 14s 12ms/step - loss: 0.2109 - accuracy: 0.9151 - auc: 0.8838 - val_loss: 0.2007 - val_accuracy: 0.9176 - val_auc: 0.8995
#
# Epoch 00003: val_accuracy improved from 0.91721 to 0.91760, saving model to model/Ensemble/CV_9\model_4.h5
# Epoch 4/100
# 1183/1183 [==============================] - 15s 12ms/step - loss: 0.2086 - accuracy: 0.9155 - auc: 0.8870 - val_loss: 0.2015 - val_accuracy: 0.9158 - val_auc: 0.9005
#
# Epoch 00004: val_accuracy did not improve from 0.91760
# Epoch 5/100
# 1183/1183 [==============================] - 14s 12ms/step - loss: 0.2070 - accuracy: 0.9163 - auc: 0.8891 - val_loss: 0.1989 - val_accuracy: 0.9178 - val_auc: 0.9016
#
# Epoch 00005: val_accuracy improved from 0.91760 to 0.91780, saving model to model/Ensemble/CV_9\model_4.h5
# Epoch 6/100
# 1183/1183 [==============================] - 15s 12ms/step - loss: 0.2060 - accuracy: 0.9166 - auc: 0.8904 - val_loss: 0.1974 - val_accuracy: 0.9181 - val_auc: 0.9034
#
# Epoch 00006: val_accuracy improved from 0.91780 to 0.91807, saving model to model/Ensemble/CV_9\model_4.h5
# Epoch 7/100
# 1183/1183 [==============================] - 15s 12ms/step - loss: 0.2049 - accuracy: 0.9169 - auc: 0.8922 - val_loss: 0.1964 - val_accuracy: 0.9191 - val_auc: 0.9043
#
# Epoch 00007: val_accuracy improved from 0.91807 to 0.91908, saving model to model/Ensemble/CV_9\model_4.h5
# Epoch 8/100
# 1183/1183 [==============================] - 15s 12ms/step - loss: 0.2044 - accuracy: 0.9173 - auc: 0.8925 - val_loss: 0.1959 - val_accuracy: 0.9186 - val_auc: 0.9047
#
# Epoch 00008: val_accuracy did not improve from 0.91908
# Epoch 9/100
# 1183/1183 [==============================] - 15s 12ms/step - loss: 0.2036 - accuracy: 0.9171 - auc: 0.8938 - val_loss: 0.1965 - val_accuracy: 0.9186 - val_auc: 0.9048
#
# Epoch 00009: val_accuracy did not improve from 0.91908
# Epoch 10/100
# 1183/1183 [==============================] - 15s 12ms/step - loss: 0.2032 - accuracy: 0.9174 - auc: 0.8942 - val_loss: 0.1952 - val_accuracy: 0.9198 - val_auc: 0.9055
#
# Epoch 00010: val_accuracy improved from 0.91908 to 0.91982, saving model to model/Ensemble/CV_9\model_4.h5
# Epoch 11/100
# 1183/1183 [==============================] - 15s 12ms/step - loss: 0.2025 - accuracy: 0.9177 - auc: 0.8949 - val_loss: 0.1959 - val_accuracy: 0.9186 - val_auc: 0.9050
#
# Epoch 00011: val_accuracy did not improve from 0.91982
# Epoch 12/100
# 1183/1183 [==============================] - 15s 12ms/step - loss: 0.2022 - accuracy: 0.9178 - auc: 0.8956 - val_loss: 0.1941 - val_accuracy: 0.9199 - val_auc: 0.9071
#
# Epoch 00012: val_accuracy improved from 0.91982 to 0.91991, saving model to model/Ensemble/CV_9\model_4.h5
# Epoch 13/100
# 1183/1183 [==============================] - 15s 12ms/step - loss: 0.2016 - accuracy: 0.9183 - auc: 0.8961 - val_loss: 0.1954 - val_accuracy: 0.9189 - val_auc: 0.9060
#
# Epoch 00013: val_accuracy did not improve from 0.91991
# Epoch 14/100
# 1183/1183 [==============================] - 15s 12ms/step - loss: 0.2013 - accuracy: 0.9180 - auc: 0.8967 - val_loss: 0.1947 - val_accuracy: 0.9192 - val_auc: 0.9067
#
# Epoch 00014: val_accuracy did not improve from 0.91991
# Epoch 15/100
# 1183/1183 [==============================] - 15s 12ms/step - loss: 0.2008 - accuracy: 0.9181 - auc: 0.8973 - val_loss: 0.1933 - val_accuracy: 0.9200 - val_auc: 0.9072
#
# Epoch 00015: val_accuracy improved from 0.91991 to 0.92000, saving model to model/Ensemble/CV_9\model_4.h5
# Epoch 16/100
# 1183/1183 [==============================] - 15s 12ms/step - loss: 0.2009 - accuracy: 0.9181 - auc: 0.8971 - val_loss: 0.1943 - val_accuracy: 0.9191 - val_auc: 0.9071
#
# Epoch 00016: val_accuracy did not improve from 0.92000
# Epoch 17/100
# 1183/1183 [==============================] - 14s 12ms/step - loss: 0.2005 - accuracy: 0.9183 - auc: 0.8977 - val_loss: 0.1939 - val_accuracy: 0.9197 - val_auc: 0.9074
#
# Epoch 00017: val_accuracy did not improve from 0.92000
# Epoch 18/100
# 1183/1183 [==============================] - 14s 12ms/step - loss: 0.2001 - accuracy: 0.9185 - auc: 0.8981 - val_loss: 0.1936 - val_accuracy: 0.9195 - val_auc: 0.9076
#
# Epoch 00018: val_accuracy did not improve from 0.92000
# Epoch 19/100
# 1183/1183 [==============================] - 14s 12ms/step - loss: 0.1999 - accuracy: 0.9185 - auc: 0.8985 - val_loss: 0.1934 - val_accuracy: 0.9193 - val_auc: 0.9078
#
# Epoch 00019: val_accuracy did not improve from 0.92000
# Epoch 20/100
# 1183/1183 [==============================] - 14s 12ms/step - loss: 0.1999 - accuracy: 0.9187 - auc: 0.8984 - val_loss: 0.1920 - val_accuracy: 0.9212 - val_auc: 0.9093
#
# Epoch 00020: val_accuracy improved from 0.92000 to 0.92116, saving model to model/Ensemble/CV_9\model_4.h5
# Epoch 21/100
# 1183/1183 [==============================] - 15s 12ms/step - loss: 0.1993 - accuracy: 0.9187 - auc: 0.8993 - val_loss: 0.1924 - val_accuracy: 0.9209 - val_auc: 0.9088
#
# Epoch 00021: val_accuracy did not improve from 0.92116
# Epoch 22/100
# 1183/1183 [==============================] - 14s 12ms/step - loss: 0.1991 - accuracy: 0.9188 - auc: 0.8994 - val_loss: 0.1925 - val_accuracy: 0.9205 - val_auc: 0.9082
#
# Epoch 00022: val_accuracy did not improve from 0.92116
# Epoch 23/100
# 1183/1183 [==============================] - 14s 12ms/step - loss: 0.1991 - accuracy: 0.9187 - auc: 0.8994 - val_loss: 0.1926 - val_accuracy: 0.9197 - val_auc: 0.9089
#
# Epoch 00023: val_accuracy did not improve from 0.92116
# Epoch 24/100
# 1183/1183 [==============================] - 14s 12ms/step - loss: 0.1990 - accuracy: 0.9187 - auc: 0.8996 - val_loss: 0.1915 - val_accuracy: 0.9206 - val_auc: 0.9094
#
# Epoch 00024: val_accuracy did not improve from 0.92116
# Epoch 25/100
# 1183/1183 [==============================] - 14s 12ms/step - loss: 0.1988 - accuracy: 0.9188 - auc: 0.9000 - val_loss: 0.1919 - val_accuracy: 0.9202 - val_auc: 0.9096
#
# Epoch 00025: val_accuracy did not improve from 0.92116
# Epoch 00025: early stopping

# %%
temp_probas=np.array([]) 
temp_labels=np.array([])

font1 = {'family' : 'Times New Roman',
        'weight' : 'normal',
        'size'   : 16}
figsize=6.2, 6.2

for u in range(10):
    pep_bal, mhc_bal, target_bal = balanced_sampling(train_pep, train_mhc, train_target)
    folder = 'model/Ensemble/CV_'+str(u)+'/'
    for i, (train, test) in enumerate(kfold.split(train_pep, train_target)):
        training_pep = train_pep[train]
        training_mhc = train_mhc[train]
        training_target = train_target[train]
        
        validation_pep = train_pep[test]
        validation_mhc = train_mhc[test]
        validation_target = train_target[test]

        savedmodel = build_model(training_pep, training_mhc)
        savedmodel.load_weights(folder+'model_'+str(i)+'.h5')
        probas_ = savedmodel.predict([np.array(validation_pep),np.array(validation_mhc)], verbose = 1)
        del savedmodel
        gc.collect()
        tf.keras.backend.clear_session()
        temp_probas = np.append(temp_probas, probas_)
        temp_labels = np.append(temp_labels, validation_target)

    if u == 0:
        fpr, tpr, threshold = roc_curve(temp_labels, temp_probas)
        auroc = auc(fpr, tpr)
        pr, rc, _ = precision_recall_curve(temp_labels, temp_probas)
        aupr = average_precision_score(temp_labels, temp_probas)

        figure1, ax1 = plt.subplots(figsize=figsize)
        ax1.tick_params(labelsize=18)
        labels = ax1.get_xticklabels() + ax1.get_yticklabels()
        [label.set_fontname('Times New Roman') for label in labels]  
        ax1.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
        label='Luck', alpha=.8)

        ax1.plot(fpr, tpr,
                label=r'Ensemble Model '+str(u)+ '(AUC = %0.4f)' % (auroc),
                    lw=2, alpha=.8)
        ax1.set_xlim([-0.05, 1.05])
        ax1.set_ylim([-0.05, 1.05])
        ax1.set_xlabel('False Positive Rate', font1)
        ax1.set_ylabel('True Positive Rate', font1)
        title1 = 'Cross Validated ROC Curve'
        ax1.set_title(title1, font1)
        ax1.legend(loc="lower right")
        
        ########PR_figure
        figure2, ax2 = plt.subplots(figsize=figsize)
        ax2.tick_params(labelsize=18)
        labels = ax2.get_xticklabels() + ax2.get_yticklabels()
        [label.set_fontname('Times New Roman') for label in labels] 

        ax2.plot(rc, pr,
                label=r'Ensemble Model '+str(u)+ '(AUC = %0.4f)' % aupr,
                lw=2, alpha=.8)

        ax2.set_xlim([-0.05, 1.05])
        ax2.set_ylim([-0.05, 1.05])
        ax2.set_xlabel('Recall', font1)
        ax2.set_ylabel('Precision', font1)
        title2 = 'Cross Validated PR Curve'
        ax2.set_title(title2, font1)
        ax2.legend(loc="lower left")
    else:
        fpr, tpr, threshold = roc_curve(temp_labels, temp_probas)
        auroc = auc(fpr, tpr)
        pr, rc, _ = precision_recall_curve(temp_labels, temp_probas)
        aupr = average_precision_score(temp_labels, temp_probas)

        ax1.plot(fpr, tpr,
        label=r'Ensemble Model '+str(u)+ '(AUC = %0.4f)' % (auroc),
            lw=2, alpha=.8)
        ax1.legend(loc="lower right")


        ax2.plot(rc, pr,
                label=r'Ensemble Model '+str(u)+ '(AUC = %0.4f)' % aupr,
                lw=2, alpha=.8)
        ax2.legend(loc='lower left')

    allprobas_ = np.append(allprobas_, temp_probas)
    all_labels = np.append(all_labels, temp_labels)

    temp_probas = np.array([])
    temp_labels = np.array([])
    gc.collect()
    tf.keras.backend.clear_session()
# Out:
# 4731/4731 [==============================] - 8s 2ms/step
# 4731/4731 [==============================] - 9s 2ms/step
# 4731/4731 [==============================] - 9s 2ms/step
# 4731/4731 [==============================] - 9s 2ms/step
# 4731/4731 [==============================] - 9s 2ms/step
# 4731/4731 [==============================] - 8s 2ms/step
# 4731/4731 [==============================] - 9s 2ms/step
# 4731/4731 [==============================] - 9s 2ms/step
# 4731/4731 [==============================] - 9s 2ms/step
# 4731/4731 [==============================] - 9s 2ms/step
# 4731/4731 [==============================] - 9s 2ms/step
# 4731/4731 [==============================] - 8s 2ms/step
# 4731/4731 [==============================] - 9s 2ms/step
# 4731/4731 [==============================] - 9s 2ms/step
# 4731/4731 [==============================] - 9s 2ms/step
# 4731/4731 [==============================] - 9s 2ms/step
# 4731/4731 [==============================] - 9s 2ms/step
# 4731/4731 [==============================] - 9s 2ms/step
# 4731/4731 [==============================] - 9s 2ms/step
# 4731/4731 [==============================] - 9s 2ms/step
# 4731/4731 [==============================] - 8s 2ms/step
# 4731/4731 [==============================] - 9s 2ms/step
# 4731/4731 [==============================] - 8s 2ms/step
# 4731/4731 [==============================] - 9s 2ms/step
# 4731/4731 [==============================] - 8s 2ms/step
# 4731/4731 [==============================] - 8s 2ms/step
# 4731/4731 [==============================] - 9s 2ms/step
# 4731/4731 [==============================] - 9s 2ms/step
# 4731/4731 [==============================] - 9s 2ms/step
# 4731/4731 [==============================] - 9s 2ms/step
# 4731/4731 [==============================] - 8s 2ms/step
# 4731/4731 [==============================] - 9s 2ms/step
# 4731/4731 [==============================] - 9s 2ms/step
# 4731/4731 [==============================] - 9s 2ms/step
# 4731/4731 [==============================] - 9s 2ms/step
# 4731/4731 [==============================] - 8s 2ms/step
# 4731/4731 [==============================] - 9s 2ms/step
# 4731/4731 [==============================] - 9s 2ms/step
# 4731/4731 [==============================] - 9s 2ms/step
# 4731/4731 [==============================] - 9s 2ms/step
# 4731/4731 [==============================] - 8s 2ms/step
# 4731/4731 [==============================] - 9s 2ms/step
# 4731/4731 [==============================] - 9s 2ms/step
# 4731/4731 [==============================] - 9s 2ms/step
# 4731/4731 [==============================] - 9s 2ms/step
# 4731/4731 [==============================] - 8s 2ms/step
# 4731/4731 [==============================] - 9s 2ms/step
# 4731/4731 [==============================] - 9s 2ms/step
# 4731/4731 [==============================] - 9s 2ms/step
# 4731/4731 [==============================] - 9s 2ms/step

# %%
font1 = {'family' : 'Times New Roman',
        'weight' : 'normal',
        'size'   : 16}
figsize=6.2, 6.2

########ROC_figure
figure1, ax1 = plt.subplots(figsize=figsize)
ax1.tick_params(labelsize=18)
labels = ax1.get_xticklabels() + ax1.get_yticklabels()
[label.set_fontname('Times New Roman') for label in labels]  

fpr, tpr, thresholds = roc_curve(all_labels, allprobas_)
roc_auc = auc(fpr, tpr)
print(roc_auc)

ax1.plot(fpr, tpr, color='b',
    label=r'Mean ROC (AUC = %0.4f)' % (roc_auc),
    lw=2, alpha=.8)
ax1.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
        label='Luck', alpha=.8)
ax1.set_xlim([-0.05, 1.05])
ax1.set_ylim([-0.05, 1.05])
ax1.set_xlabel('False Positive Rate', font1)
ax1.set_ylabel('True Positive Rate', font1)
title1 = 'Cross Validated ROC Curve'
ax1.set_title(title1, font1)
ax1.legend(loc="lower right")
#figure1.savefig('figures/balancedCV_mean_5_fold_roc.jpg', dpi=300, bbox_inches = 'tight')

########PR_figure
figure2, ax2 = plt.subplots(figsize=figsize)
ax2.tick_params(labelsize=18)
labels = ax2.get_xticklabels() + ax2.get_yticklabels()
[label.set_fontname('Times New Roman') for label in labels] 

precision, recall, _ = precision_recall_curve(all_labels, allprobas_)
ax2.plot(recall, precision, color='b',
        label=r'Mean Precision-Recall (AUC = %0.4f)' % (average_precision_score(all_labels, allprobas_)),
        lw=2, alpha=.8)

ax2.set_xlim([-0.05, 1.05])
ax2.set_ylim([-0.05, 1.05])
ax2.set_xlabel('Recall', font1)
ax2.set_ylabel('Precision', font1)
title2 = 'Cross Validated PR Curve'
ax2.set_title(title2, font1)
ax2.legend(loc="lower left")
#figure2.savefig('figures/balancedCV_mean_5_fold_pr.jpg', dpi=300, bbox_inches = 'tight')
# Out:
# 0.9040877186873335

# %%
temp_probas2=np.array([])
temp_labels2=np.array([])
allprobas2_=np.array([]) 
all_labels2=np.array([])

font1 = {'family' : 'Times New Roman',
        'weight' : 'normal',
        'size'   : 16}
figsize=6.2, 6.2

for u in range(10):
    pep_bal, mhc_bal, target_bal = balanced_sampling(test_pep, test_mhc, test_target)
    folder = 'model/Ensemble/CV_'+str(u)+'/'
    for i, (train, test) in enumerate(kfold.split(test_pep, test_target)):
        training_pep = test_pep[train]
        training_mhc = test_mhc[train]
        training_target = test_target[train]
        
        validation_pep = test_pep[test]
        validation_mhc = test_mhc[test]
        validation_target = test_target[test]

        savedmodel = build_model(test_pep, test_mhc)
        savedmodel.load_weights(folder+'model_'+str(i)+'.h5')
        probas_ = savedmodel.predict([np.array(validation_pep),np.array(validation_mhc)], verbose = 1)
        del savedmodel
        gc.collect()
        tf.keras.backend.clear_session()
        temp_probas2 = np.append(temp_probas2, probas_)
        temp_labels2 = np.append(temp_labels2, validation_target)

    if u == 0:
        fpr, tpr, threshold = roc_curve(temp_labels2, temp_probas2)
        auroc = auc(fpr, tpr)
        pr, rc, _ = precision_recall_curve(temp_labels2, temp_probas2)
        aupr = average_precision_score(temp_labels2, temp_probas2)

        figure1, ax1 = plt.subplots(figsize=figsize)
        ax1.tick_params(labelsize=18)
        labels = ax1.get_xticklabels() + ax1.get_yticklabels()
        [label.set_fontname('Times New Roman') for label in labels]  
        ax1.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
        label='Luck', alpha=.8)

        ax1.plot(fpr, tpr,
                label=r'Ensemble Model '+str(u)+ '(AUC = %0.4f)' % (auroc),
                    lw=2, alpha=.8)
        ax1.set_xlim([-0.05, 1.05])
        ax1.set_ylim([-0.05, 1.05])
        ax1.set_xlabel('False Positive Rate', font1)
        ax1.set_ylabel('True Positive Rate', font1)
        title1 = 'Cross Validated ROC Curve'
        ax1.set_title(title1, font1)
        ax1.legend(loc="lower right")
        
        ########PR_figure
        figure2, ax2 = plt.subplots(figsize=figsize)
        ax2.tick_params(labelsize=18)
        labels = ax2.get_xticklabels() + ax2.get_yticklabels()
        [label.set_fontname('Times New Roman') for label in labels] 

        ax2.plot(rc, pr,
                label=r'Ensemble Model '+str(u)+ '(AUC = %0.4f)' % aupr,
                lw=2, alpha=.8)

        ax2.set_xlim([-0.05, 1.05])
        ax2.set_ylim([-0.05, 1.05])
        ax2.set_xlabel('Recall', font1)
        ax2.set_ylabel('Precision', font1)
        title2 = 'Cross Validated PR Curve'
        ax2.set_title(title2, font1)
        ax2.legend(loc="lower left")
    else:
        fpr, tpr, threshold = roc_curve(temp_labels2, temp_probas2)
        auroc = auc(fpr, tpr)
        pr, rc, _ = precision_recall_curve(temp_labels2, temp_probas2)
        aupr = average_precision_score(temp_labels2, temp_probas2)

        ax1.plot(fpr, tpr,
        label=r'Ensemble Model '+str(u)+ '(AUC = %0.4f)' % (auroc),
            lw=2, alpha=.8)
        ax1.legend(loc="lower right")


        ax2.plot(rc, pr,
                label=r'Ensemble Model '+str(u)+ '(AUC = %0.4f)' % aupr,
                lw=2, alpha=.8)
        ax2.legend(loc='lower left')

    allprobas2_ = np.append(allprobas2_, temp_probas2)
    all_labels2 = np.append(all_labels2, temp_labels2)

    temp_probas2 = np.array([])
    temp_labels2 = np.array([])
    gc.collect()
    tf.keras.backend.clear_session()
# Out:
# 1183/1183 [==============================] - 3s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 3s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 3s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 3s 2ms/step
# 1183/1183 [==============================] - 3s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step
# 1183/1183 [==============================] - 2s 2ms/step

# %%
font1 = {'family' : 'Times New Roman',
        'weight' : 'normal',
        'size'   : 16}
figsize=6.2, 6.2

########ROC_figure
figure1, ax1 = plt.subplots(figsize=figsize)
ax1.tick_params(labelsize=18)
labels = ax1.get_xticklabels() + ax1.get_yticklabels()
[label.set_fontname('Times New Roman') for label in labels]  

fpr, tpr, thresholds = roc_curve(all_labels2, allprobas2_)
roc_auc = auc(fpr, tpr)
print(roc_auc)

ax1.plot(fpr, tpr, color='b',
    label=r'Mean ROC (AUC = %0.4f)' % (roc_auc),
    lw=2, alpha=.8)
ax1.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
        label='Luck', alpha=.8)
ax1.set_xlim([-0.05, 1.05])
ax1.set_ylim([-0.05, 1.05])
ax1.set_xlabel('False Positive Rate', font1)
ax1.set_ylabel('True Positive Rate', font1)
title1 = 'Cross Validated ROC Curve'
ax1.set_title(title1, font1)
ax1.legend(loc="lower right")
#figure1.savefig('figures/balancedCV_test_mean_5_fold_roc.jpg', dpi=300, bbox_inches = 'tight')

########PR_figure
figure2, ax2 = plt.subplots(figsize=figsize)
ax2.tick_params(labelsize=18)
labels = ax2.get_xticklabels() + ax2.get_yticklabels()
[label.set_fontname('Times New Roman') for label in labels] 

precision, recall, _ = precision_recall_curve(all_labels2, allprobas2_)
ax2.plot(recall, precision, color='b',
        label=r'Mean Precision-Recall (AUC = %0.4f)' % (average_precision_score(all_labels2, allprobas2_)),
        lw=2, alpha=.8)

ax2.set_xlim([-0.05, 1.05])
ax2.set_ylim([-0.05, 1.05])
ax2.set_xlabel('Recall', font1)
ax2.set_ylabel('Precision', font1)
title2 = 'Cross Validated PR Curve'
ax2.set_title(title2, font1)
ax2.legend(loc="lower left")
#figure2.savefig('figures/balancedCV_test_mean_5_fold_pr.jpg', dpi=300, bbox_inches = 'tight')
# Out:
# 0.9044304671302944
