# %%
"""
Created on August 31 2022

@author: JJ
"""
# Out:
# '\nCreated on August 31 2022\n\n@author: JJ\n'

# %%
import os, re, sys
import numpy as np
import pandas as pd
from math import log
import random
import scipy.io
import tensorflow as tf
import csv
# Out:
# 2022-09-27 14:11:45.648450: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
from tensorflow.keras.optimizers import *
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.constraints import MaxNorm
from tensorflow.keras.regularizers import (
    l2, 
    l1, 
    l1_l2
)
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras import (
    activations, 
    initializers, 
    regularizers, 
    constraints
)

# %%
#import from python files
from model import build_model

# %%
num_threads = 8
# Maximum number of threads to use for OpenMP parallel regions.
os.environ["OMP_NUM_THREADS"] = "8"
# Without setting below 2 environment variables, it didn't work for me. Thanks to @cjw85 
os.environ["TF_NUM_INTRAOP_THREADS"] = "4"
os.environ["TF_NUM_INTEROP_THREADS"] = "4"

tf.config.threading.set_inter_op_parallelism_threads(
    num_threads
)
tf.config.threading.set_intra_op_parallelism_threads(
    num_threads
)
tf.config.set_soft_device_placement(True)

# %%
# in a well-defined initial state.
random.seed
np.random.seed(1337)
tf.random.set_seed(1337)

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
from tensorflow.keras.callbacks import (
    ModelCheckpoint, 
    EarlyStopping
)
from sklearn.metrics import (
    roc_curve,
    auc,
    roc_auc_score,
    average_precision_score,
    precision_recall_curve,
)

# %%
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.utils import resample, shuffle
from sklearn.feature_selection import (
    SelectKBest,
    chi2
)
import keras_tuner as kt
from collections import defaultdict

# %%
all_pep, all_mhc, all_target = np.load('/home/jjia1/jjia1/viralepitope/all_pep_converted.npy'), np.load('/home/jjia1/jjia1/viralepitope/all_mhc_converted.npy'), np.load('/home/jjia1/jjia1/viralepitope/all_target_converted.npy')

# %%
pos = np.where(all_target==1)
pep_pos = all_pep[pos]

# %%
def balanced_sampling(pep, mhc, target):
    pos = np.where(target==1)
    neg = np.where(target==0)

    pep_pos, mhc_pos, target_pos = pep[pos], mhc[pos], target[pos]
    pep_neg, mhc_neg, target_neg = pep[neg], mhc[neg], target[neg]

    pep_pos, mhc_pos, target_pos = resample(pep_pos, mhc_pos, target_pos, n_samples= len(target_pos), random_state = 1337)
    pep_neg, mhc_neg, target_neg = resample(pep_neg, mhc_neg, target_neg, n_samples= len(target_pos), random_state = 1337)


    pep = np.concatenate([pep_pos, pep_neg])
    mhc = np.concatenate([mhc_pos, mhc_neg])
    target = np.concatenate([target_pos, target_neg])

    pep, mhc, target = shuffle(pep, mhc, target, random_state = 1337)
    return pep, mhc, target

# %%
pep_bal, mhc_bal, target_bal = balanced_sampling(all_pep, all_mhc, all_target)

# %%
es = EarlyStopping(monitor = 'val_accuracy', mode = 'max', verbose = 1, patience = 5)

# %%
train_pep, test_pep, train_mhc, test_mhc, train_target, test_target = train_test_split(pep_bal, mhc_bal, target_bal, test_size = 0.2, stratify= target_bal)

# %%
print(train_pep.shape)
print(test_pep.shape)
# Out:
# (137494, 30, 20)
# (34374, 30, 20)

# %%
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=1337)    
allprobas_=np.array([]) 
all_labels=np.array([])

# %%
for i, (train, test) in enumerate(kfold.split(train_pep, train_target)):
    training_pep = train_pep[train]
    training_mhc = train_mhc[train]
    training_target = train_target[train]
    
    validation_pep = train_pep[test]
    validation_mhc = train_mhc[test]
    validation_target = train_target[test]

    mc = ModelCheckpoint('model/balanced_CV/model_' +str(i)+'.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
    model = build_model(training_pep, training_mhc)
    model.summary()

    model.fit([training_pep,training_mhc], 
            training_target,
            batch_size=512,
            epochs = 100,
            shuffle=True,
            callbacks=[es, mc],
            validation_data=([validation_pep,validation_mhc], validation_target),
            verbose=1)  
    del model

    saved_model = build_model(training_pep, training_mhc)
    saved_model.load_weights('model/balanced_CV/model_' +str(i)+'.h5')
    probas_ = saved_model.predict([np.array(validation_pep),np.array(validation_mhc)])
    allprobas_ = np.append(allprobas_, probas_)           
    all_labels = np.append(all_labels, validation_target)
    del saved_model
# Out:
# 2022-09-27 14:13:26.045407: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-09-27 14:13:26.046519: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-09-27 14:13:26.046555: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-09-27 14:13:26.046592: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (sbcphaplp001.uthouston.edu): /proc/driver/nvidia/version does not exist
# 2022-09-27 14:13:26.047079: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-27 14:13:26.047733: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# WARNING:tensorflow:AutoGraph could not transform <bound method attention_flatten.call of <attention_layer.attention_flatten object at 0x7fa0cceec4f0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method attention_flatten.call of <attention_layer.attention_flatten object at 0x7fa0cceec4f0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# peptide (InputLayer)            [(None, 30, 20)]     0
# __________________________________________________________________________________________________
# mhc (InputLayer)                [(None, 34, 20)]     0
# __________________________________________________________________________________________________
# conv1_pep (Conv1D)              (None, 30, 128)      7808        peptide[0][0]
# __________________________________________________________________________________________________
# conv1_mhc (Conv1D)              (None, 34, 128)      7808        mhc[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 15, 128)      0           conv1_pep[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 17, 128)      0           conv1_mhc[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 15, 128)      0           max_pooling1d[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 17, 128)      0           max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1920)         0           dropout[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2176)         0           dropout_2[0][0]
# __________________________________________________________________________________________________
# attention (Attention)           (None, 143)          33281       dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1920)         0           flatten[0][0]
# __________________________________________________________________________________________________
# attention_1 (Attention)         (None, 145)          33281       dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 2176)         0           flatten_1[0][0]
# __________________________________________________________________________________________________
# attention_flatten (attention_fl (None, 128)          0           attention[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            1921        dropout_1[0][0]
# __________________________________________________________________________________________________
# attention_flatten_1 (attention_ (None, 128)          0           attention_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            2177        dropout_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 129)          0           attention_flatten[0][0]
#                                                                  dense[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 129)          0           attention_flatten_1[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            130         concatenate[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            130         concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 2)            0           dense_1[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            3           concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 1)            0           dense_4[0][0]
# ==================================================================================================
# Total params: 86,539
# Trainable params: 86,539
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 2022-09-27 14:13:29.318078: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-09-27 14:13:29.326354: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2200000000 Hz
# Epoch 1/100
# 215/215 [==============================] - 43s 176ms/step - loss: 0.5836 - accuracy: 0.6844 - auc: 0.7531 - val_loss: 0.4554 - val_accuracy: 0.7918 - val_auc: 0.8671
#
# Epoch 00001: val_accuracy improved from -inf to 0.79181, saving model to model/balanced_CV/model_0.h5
# Epoch 2/100
# 215/215 [==============================] - 36s 166ms/step - loss: 0.4687 - accuracy: 0.7793 - auc: 0.8552 - val_loss: 0.4312 - val_accuracy: 0.8031 - val_auc: 0.8839
#
# Epoch 00002: val_accuracy improved from 0.79181 to 0.80312, saving model to model/balanced_CV/model_0.h5
# Epoch 3/100
# 215/215 [==============================] - 19s 87ms/step - loss: 0.4447 - accuracy: 0.7969 - auc: 0.8713 - val_loss: 0.4147 - val_accuracy: 0.8167 - val_auc: 0.8911
#
# Epoch 00003: val_accuracy improved from 0.80312 to 0.81672, saving model to model/balanced_CV/model_0.h5
# Epoch 4/100
# 215/215 [==============================] - 20s 92ms/step - loss: 0.4328 - accuracy: 0.8052 - auc: 0.8789 - val_loss: 0.4100 - val_accuracy: 0.8207 - val_auc: 0.8948
#
# Epoch 00004: val_accuracy improved from 0.81672 to 0.82072, saving model to model/balanced_CV/model_0.h5
# Epoch 5/100
# 215/215 [==============================] - 36s 168ms/step - loss: 0.4251 - accuracy: 0.8086 - auc: 0.8836 - val_loss: 0.4030 - val_accuracy: 0.8222 - val_auc: 0.8962
#
# Epoch 00005: val_accuracy improved from 0.82072 to 0.82218, saving model to model/balanced_CV/model_0.h5
# Epoch 6/100
# 215/215 [==============================] - 35s 163ms/step - loss: 0.4220 - accuracy: 0.8109 - auc: 0.8855 - val_loss: 0.4003 - val_accuracy: 0.8231 - val_auc: 0.8981
#
# Epoch 00006: val_accuracy improved from 0.82218 to 0.82308, saving model to model/balanced_CV/model_0.h5
# Epoch 7/100
# 215/215 [==============================] - 42s 194ms/step - loss: 0.4140 - accuracy: 0.8166 - auc: 0.8896 - val_loss: 0.4000 - val_accuracy: 0.8231 - val_auc: 0.8988
#
# Epoch 00007: val_accuracy did not improve from 0.82308
# Epoch 8/100
# 215/215 [==============================] - 43s 199ms/step - loss: 0.4158 - accuracy: 0.8145 - auc: 0.8889 - val_loss: 0.3956 - val_accuracy: 0.8253 - val_auc: 0.8999
#
# Epoch 00008: val_accuracy improved from 0.82308 to 0.82527, saving model to model/balanced_CV/model_0.h5
# Epoch 9/100
# 215/215 [==============================] - 38s 178ms/step - loss: 0.4107 - accuracy: 0.8167 - auc: 0.8917 - val_loss: 0.3947 - val_accuracy: 0.8269 - val_auc: 0.9012
#
# Epoch 00009: val_accuracy improved from 0.82527 to 0.82694, saving model to model/balanced_CV/model_0.h5
# Epoch 10/100
# 215/215 [==============================] - 35s 161ms/step - loss: 0.4106 - accuracy: 0.8181 - auc: 0.8919 - val_loss: 0.3931 - val_accuracy: 0.8272 - val_auc: 0.9014
#
# Epoch 00010: val_accuracy improved from 0.82694 to 0.82723, saving model to model/balanced_CV/model_0.h5
# Epoch 11/100
# 215/215 [==============================] - 21s 97ms/step - loss: 0.4115 - accuracy: 0.8183 - auc: 0.8912 - val_loss: 0.3927 - val_accuracy: 0.8277 - val_auc: 0.9016
#
# Epoch 00011: val_accuracy improved from 0.82723 to 0.82774, saving model to model/balanced_CV/model_0.h5
# Epoch 12/100
# 215/215 [==============================] - 20s 93ms/step - loss: 0.4098 - accuracy: 0.8180 - auc: 0.8924 - val_loss: 0.3920 - val_accuracy: 0.8278 - val_auc: 0.9020
#
# Epoch 00012: val_accuracy improved from 0.82774 to 0.82778, saving model to model/balanced_CV/model_0.h5
# Epoch 13/100
# 215/215 [==============================] - 13s 59ms/step - loss: 0.4059 - accuracy: 0.8220 - auc: 0.8947 - val_loss: 0.3893 - val_accuracy: 0.8297 - val_auc: 0.9030
#
# Epoch 00013: val_accuracy improved from 0.82778 to 0.82970, saving model to model/balanced_CV/model_0.h5
# Epoch 14/100
# 215/215 [==============================] - 13s 62ms/step - loss: 0.4048 - accuracy: 0.8218 - auc: 0.8954 - val_loss: 0.3899 - val_accuracy: 0.8302 - val_auc: 0.9034
#
# Epoch 00014: val_accuracy improved from 0.82970 to 0.83025, saving model to model/balanced_CV/model_0.h5
# Epoch 15/100
# 215/215 [==============================] - 15s 71ms/step - loss: 0.4044 - accuracy: 0.8219 - auc: 0.8955 - val_loss: 0.3891 - val_accuracy: 0.8294 - val_auc: 0.9037
#
# Epoch 00015: val_accuracy did not improve from 0.83025
# Epoch 16/100
# 215/215 [==============================] - 31s 143ms/step - loss: 0.4069 - accuracy: 0.8197 - auc: 0.8938 - val_loss: 0.3878 - val_accuracy: 0.8300 - val_auc: 0.9040
#
# Epoch 00016: val_accuracy did not improve from 0.83025
# Epoch 17/100
# 215/215 [==============================] - 24s 113ms/step - loss: 0.4034 - accuracy: 0.8213 - auc: 0.8958 - val_loss: 0.3880 - val_accuracy: 0.8306 - val_auc: 0.9041
#
# Epoch 00017: val_accuracy improved from 0.83025 to 0.83061, saving model to model/balanced_CV/model_0.h5
# Epoch 18/100
# 215/215 [==============================] - 33s 152ms/step - loss: 0.4039 - accuracy: 0.8215 - auc: 0.8956 - val_loss: 0.3873 - val_accuracy: 0.8311 - val_auc: 0.9040
#
# Epoch 00018: val_accuracy improved from 0.83061 to 0.83108, saving model to model/balanced_CV/model_0.h5
# Epoch 19/100
# 215/215 [==============================] - 34s 156ms/step - loss: 0.4009 - accuracy: 0.8231 - auc: 0.8968 - val_loss: 0.3883 - val_accuracy: 0.8309 - val_auc: 0.9046
#
# Epoch 00019: val_accuracy did not improve from 0.83108
# Epoch 20/100
# 215/215 [==============================] - 32s 151ms/step - loss: 0.4009 - accuracy: 0.8228 - auc: 0.8969 - val_loss: 0.3866 - val_accuracy: 0.8309 - val_auc: 0.9050
#
# Epoch 00020: val_accuracy did not improve from 0.83108
# Epoch 21/100
# 215/215 [==============================] - 28s 129ms/step - loss: 0.3996 - accuracy: 0.8247 - auc: 0.8980 - val_loss: 0.3871 - val_accuracy: 0.8295 - val_auc: 0.9049
#
# Epoch 00021: val_accuracy did not improve from 0.83108
# Epoch 22/100
# 215/215 [==============================] - 27s 125ms/step - loss: 0.4019 - accuracy: 0.8235 - auc: 0.8967 - val_loss: 0.3859 - val_accuracy: 0.8305 - val_auc: 0.9054
#
# Epoch 00022: val_accuracy did not improve from 0.83108
# Epoch 23/100
# 215/215 [==============================] - 27s 125ms/step - loss: 0.3967 - accuracy: 0.8224 - auc: 0.8994 - val_loss: 0.3850 - val_accuracy: 0.8317 - val_auc: 0.9055
#
# Epoch 00023: val_accuracy improved from 0.83108 to 0.83167, saving model to model/balanced_CV/model_0.h5
# Epoch 24/100
# 215/215 [==============================] - 30s 138ms/step - loss: 0.3952 - accuracy: 0.8262 - auc: 0.9006 - val_loss: 0.3850 - val_accuracy: 0.8320 - val_auc: 0.9057
#
# Epoch 00024: val_accuracy improved from 0.83167 to 0.83199, saving model to model/balanced_CV/model_0.h5
# Epoch 25/100
# 215/215 [==============================] - 26s 123ms/step - loss: 0.3963 - accuracy: 0.8255 - auc: 0.8994 - val_loss: 0.3838 - val_accuracy: 0.8318 - val_auc: 0.9057
#
# Epoch 00025: val_accuracy did not improve from 0.83199
# Epoch 26/100
# 215/215 [==============================] - 36s 166ms/step - loss: 0.3991 - accuracy: 0.8238 - auc: 0.8978 - val_loss: 0.3840 - val_accuracy: 0.8309 - val_auc: 0.9060
#
# Epoch 00026: val_accuracy did not improve from 0.83199
# Epoch 27/100
# 215/215 [==============================] - 32s 148ms/step - loss: 0.3997 - accuracy: 0.8230 - auc: 0.8979 - val_loss: 0.3829 - val_accuracy: 0.8319 - val_auc: 0.9065
#
# Epoch 00027: val_accuracy did not improve from 0.83199
# Epoch 28/100
# 215/215 [==============================] - 32s 151ms/step - loss: 0.3987 - accuracy: 0.8229 - auc: 0.8977 - val_loss: 0.3828 - val_accuracy: 0.8324 - val_auc: 0.9063
#
# Epoch 00028: val_accuracy improved from 0.83199 to 0.83243, saving model to model/balanced_CV/model_0.h5
# Epoch 29/100
# 215/215 [==============================] - 14s 64ms/step - loss: 0.3960 - accuracy: 0.8260 - auc: 0.8998 - val_loss: 0.3832 - val_accuracy: 0.8323 - val_auc: 0.9064
#
# Epoch 00029: val_accuracy did not improve from 0.83243
# Epoch 30/100
# 215/215 [==============================] - 14s 64ms/step - loss: 0.3955 - accuracy: 0.8249 - auc: 0.9000 - val_loss: 0.3827 - val_accuracy: 0.8323 - val_auc: 0.9067
#
# Epoch 00030: val_accuracy did not improve from 0.83243
# Epoch 31/100
# 215/215 [==============================] - 15s 72ms/step - loss: 0.3967 - accuracy: 0.8262 - auc: 0.8995 - val_loss: 0.3837 - val_accuracy: 0.8324 - val_auc: 0.9069
#
# Epoch 00031: val_accuracy did not improve from 0.83243
# Epoch 32/100
# 215/215 [==============================] - 12s 57ms/step - loss: 0.3951 - accuracy: 0.8281 - auc: 0.9001 - val_loss: 0.3849 - val_accuracy: 0.8321 - val_auc: 0.9070
#
# Epoch 00032: val_accuracy did not improve from 0.83243
# Epoch 33/100
# 215/215 [==============================] - 12s 54ms/step - loss: 0.3945 - accuracy: 0.8266 - auc: 0.9006 - val_loss: 0.3818 - val_accuracy: 0.8325 - val_auc: 0.9069
#
# Epoch 00033: val_accuracy improved from 0.83243 to 0.83247, saving model to model/balanced_CV/model_0.h5
# Epoch 34/100
# 215/215 [==============================] - 14s 63ms/step - loss: 0.3915 - accuracy: 0.8273 - auc: 0.9018 - val_loss: 0.3826 - val_accuracy: 0.8325 - val_auc: 0.9073
#
# Epoch 00034: val_accuracy improved from 0.83247 to 0.83254, saving model to model/balanced_CV/model_0.h5
# Epoch 35/100
# 215/215 [==============================] - 15s 69ms/step - loss: 0.3924 - accuracy: 0.8285 - auc: 0.9015 - val_loss: 0.3811 - val_accuracy: 0.8332 - val_auc: 0.9071
#
# Epoch 00035: val_accuracy improved from 0.83254 to 0.83316, saving model to model/balanced_CV/model_0.h5
# Epoch 36/100
# 215/215 [==============================] - 13s 59ms/step - loss: 0.3948 - accuracy: 0.8259 - auc: 0.9007 - val_loss: 0.3818 - val_accuracy: 0.8334 - val_auc: 0.9076
#
# Epoch 00036: val_accuracy improved from 0.83316 to 0.83338, saving model to model/balanced_CV/model_0.h5
# Epoch 37/100
# 215/215 [==============================] - 14s 63ms/step - loss: 0.3909 - accuracy: 0.8279 - auc: 0.9028 - val_loss: 0.3804 - val_accuracy: 0.8344 - val_auc: 0.9076
#
# Epoch 00037: val_accuracy improved from 0.83338 to 0.83439, saving model to model/balanced_CV/model_0.h5
# Epoch 38/100
# 215/215 [==============================] - 14s 67ms/step - loss: 0.3910 - accuracy: 0.8273 - auc: 0.9024 - val_loss: 0.3801 - val_accuracy: 0.8342 - val_auc: 0.9078
#
# Epoch 00038: val_accuracy did not improve from 0.83439
# Epoch 39/100
# 215/215 [==============================] - 11s 53ms/step - loss: 0.3902 - accuracy: 0.8285 - auc: 0.9026 - val_loss: 0.3802 - val_accuracy: 0.8331 - val_auc: 0.9076
#
# Epoch 00039: val_accuracy did not improve from 0.83439
# Epoch 40/100
# 215/215 [==============================] - 12s 54ms/step - loss: 0.3933 - accuracy: 0.8271 - auc: 0.9011 - val_loss: 0.3793 - val_accuracy: 0.8344 - val_auc: 0.9079
#
# Epoch 00040: val_accuracy did not improve from 0.83439
# Epoch 41/100
# 215/215 [==============================] - 14s 64ms/step - loss: 0.3892 - accuracy: 0.8276 - auc: 0.9033 - val_loss: 0.3817 - val_accuracy: 0.8342 - val_auc: 0.9078
#
# Epoch 00041: val_accuracy did not improve from 0.83439
# Epoch 42/100
# 215/215 [==============================] - 30s 141ms/step - loss: 0.3922 - accuracy: 0.8266 - auc: 0.9017 - val_loss: 0.3794 - val_accuracy: 0.8356 - val_auc: 0.9082
#
# Epoch 00042: val_accuracy improved from 0.83439 to 0.83563, saving model to model/balanced_CV/model_0.h5
# Epoch 43/100
# 215/215 [==============================] - 34s 160ms/step - loss: 0.3905 - accuracy: 0.8279 - auc: 0.9024 - val_loss: 0.3788 - val_accuracy: 0.8350 - val_auc: 0.9083
#
# Epoch 00043: val_accuracy did not improve from 0.83563
# Epoch 44/100
# 215/215 [==============================] - 35s 162ms/step - loss: 0.3920 - accuracy: 0.8269 - auc: 0.9018 - val_loss: 0.3785 - val_accuracy: 0.8346 - val_auc: 0.9083
#
# Epoch 00044: val_accuracy did not improve from 0.83563
# Epoch 45/100
# 215/215 [==============================] - 34s 160ms/step - loss: 0.3882 - accuracy: 0.8295 - auc: 0.9034 - val_loss: 0.3788 - val_accuracy: 0.8343 - val_auc: 0.9082
#
# Epoch 00045: val_accuracy did not improve from 0.83563
# Epoch 46/100
# 215/215 [==============================] - 32s 149ms/step - loss: 0.3890 - accuracy: 0.8301 - auc: 0.9035 - val_loss: 0.3820 - val_accuracy: 0.8324 - val_auc: 0.9085
#
# Epoch 00046: val_accuracy did not improve from 0.83563
# Epoch 47/100
# 215/215 [==============================] - 22s 102ms/step - loss: 0.3908 - accuracy: 0.8287 - auc: 0.9027 - val_loss: 0.3786 - val_accuracy: 0.8346 - val_auc: 0.9084
#
# Epoch 00047: val_accuracy did not improve from 0.83563
# Epoch 00047: early stopping
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# peptide (InputLayer)            [(None, 30, 20)]     0
# __________________________________________________________________________________________________
# mhc (InputLayer)                [(None, 34, 20)]     0
# __________________________________________________________________________________________________
# conv1_pep (Conv1D)              (None, 30, 128)      7808        peptide[0][0]
# __________________________________________________________________________________________________
# conv1_mhc (Conv1D)              (None, 34, 128)      7808        mhc[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 15, 128)      0           conv1_pep[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 17, 128)      0           conv1_mhc[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 15, 128)      0           max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 17, 128)      0           max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 1920)         0           dropout_8[0][0]
# __________________________________________________________________________________________________
# flatten_5 (Flatten)             (None, 2176)         0           dropout_10[0][0]
# __________________________________________________________________________________________________
# attention_4 (Attention)         (None, 143)          33281       dropout_8[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 1920)         0           flatten_4[0][0]
# __________________________________________________________________________________________________
# attention_5 (Attention)         (None, 145)          33281       dropout_10[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 2176)         0           flatten_5[0][0]
# __________________________________________________________________________________________________
# attention_flatten_4 (attention_ (None, 128)          0           attention_4[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 1)            1921        dropout_9[0][0]
# __________________________________________________________________________________________________
# attention_flatten_5 (attention_ (None, 128)          0           attention_5[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 1)            2177        dropout_11[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 129)          0           attention_flatten_4[0][0]
#                                                                  dense_10[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 129)          0           attention_flatten_5[0][0]
#                                                                  dense_12[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 1)            130         concatenate_6[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 1)            130         concatenate_7[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 2)            0           dense_11[0][0]
#                                                                  dense_13[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 1)            3           concatenate_8[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 1)            0           dense_14[0][0]
# ==================================================================================================
# Total params: 86,539
# Trainable params: 86,539
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/100
# 215/215 [==============================] - 22s 92ms/step - loss: 0.5994 - accuracy: 0.6739 - auc: 0.7392 - val_loss: 0.4786 - val_accuracy: 0.7782 - val_auc: 0.8522
#
# Epoch 00001: val_accuracy improved from -inf to 0.77821, saving model to model/balanced_CV/model_1.h5
# Epoch 2/100
# 215/215 [==============================] - 18s 83ms/step - loss: 0.4809 - accuracy: 0.7717 - auc: 0.8476 - val_loss: 0.4415 - val_accuracy: 0.8002 - val_auc: 0.8743
#
# Epoch 00002: val_accuracy improved from 0.77821 to 0.80021, saving model to model/balanced_CV/model_1.h5
# Epoch 3/100
# 215/215 [==============================] - 12s 55ms/step - loss: 0.4502 - accuracy: 0.7938 - auc: 0.8674 - val_loss: 0.4241 - val_accuracy: 0.8117 - val_auc: 0.8838
#
# Epoch 00003: val_accuracy improved from 0.80021 to 0.81167, saving model to model/balanced_CV/model_1.h5
# Epoch 4/100
# 215/215 [==============================] - 19s 89ms/step - loss: 0.4378 - accuracy: 0.8015 - auc: 0.8760 - val_loss: 0.4152 - val_accuracy: 0.8169 - val_auc: 0.8894
#
# Epoch 00004: val_accuracy improved from 0.81167 to 0.81694, saving model to model/balanced_CV/model_1.h5
# Epoch 5/100
# 215/215 [==============================] - 28s 130ms/step - loss: 0.4303 - accuracy: 0.8071 - auc: 0.8802 - val_loss: 0.4090 - val_accuracy: 0.8212 - val_auc: 0.8930
#
# Epoch 00005: val_accuracy improved from 0.81694 to 0.82119, saving model to model/balanced_CV/model_1.h5
# Epoch 6/100
# 215/215 [==============================] - 24s 114ms/step - loss: 0.4242 - accuracy: 0.8101 - auc: 0.8844 - val_loss: 0.4043 - val_accuracy: 0.8242 - val_auc: 0.8949
#
# Epoch 00006: val_accuracy improved from 0.82119 to 0.82425, saving model to model/balanced_CV/model_1.h5
# Epoch 7/100
# 215/215 [==============================] - 34s 157ms/step - loss: 0.4225 - accuracy: 0.8109 - auc: 0.8848 - val_loss: 0.4017 - val_accuracy: 0.8241 - val_auc: 0.8968
#
# Epoch 00007: val_accuracy did not improve from 0.82425
# Epoch 8/100
# 215/215 [==============================] - 34s 158ms/step - loss: 0.4170 - accuracy: 0.8147 - auc: 0.8883 - val_loss: 0.3997 - val_accuracy: 0.8277 - val_auc: 0.8974
#
# Epoch 00008: val_accuracy improved from 0.82425 to 0.82770, saving model to model/balanced_CV/model_1.h5
# Epoch 9/100
# 215/215 [==============================] - 34s 157ms/step - loss: 0.4165 - accuracy: 0.8163 - auc: 0.8889 - val_loss: 0.3986 - val_accuracy: 0.8270 - val_auc: 0.8988
#
# Epoch 00009: val_accuracy did not improve from 0.82770
# Epoch 10/100
# 215/215 [==============================] - 28s 131ms/step - loss: 0.4138 - accuracy: 0.8180 - auc: 0.8899 - val_loss: 0.3965 - val_accuracy: 0.8289 - val_auc: 0.8994
#
# Epoch 00010: val_accuracy improved from 0.82770 to 0.82890, saving model to model/balanced_CV/model_1.h5
# Epoch 11/100
# 215/215 [==============================] - 35s 163ms/step - loss: 0.4113 - accuracy: 0.8188 - auc: 0.8911 - val_loss: 0.3969 - val_accuracy: 0.8272 - val_auc: 0.9000
#
# Epoch 00011: val_accuracy did not improve from 0.82890
# Epoch 12/100
# 215/215 [==============================] - 46s 216ms/step - loss: 0.4098 - accuracy: 0.8175 - auc: 0.8921 - val_loss: 0.3939 - val_accuracy: 0.8298 - val_auc: 0.9010
#
# Epoch 00012: val_accuracy improved from 0.82890 to 0.82981, saving model to model/balanced_CV/model_1.h5
# Epoch 13/100
# 215/215 [==============================] - 39s 180ms/step - loss: 0.4074 - accuracy: 0.8199 - auc: 0.8936 - val_loss: 0.3934 - val_accuracy: 0.8308 - val_auc: 0.9018
#
# Epoch 00013: val_accuracy improved from 0.82981 to 0.83079, saving model to model/balanced_CV/model_1.h5
# Epoch 14/100
# 215/215 [==============================] - 41s 191ms/step - loss: 0.4085 - accuracy: 0.8172 - auc: 0.8929 - val_loss: 0.3921 - val_accuracy: 0.8299 - val_auc: 0.9018
#
# Epoch 00014: val_accuracy did not improve from 0.83079
# Epoch 15/100
# 215/215 [==============================] - 36s 170ms/step - loss: 0.4079 - accuracy: 0.8179 - auc: 0.8931 - val_loss: 0.3937 - val_accuracy: 0.8312 - val_auc: 0.9023
#
# Epoch 00015: val_accuracy improved from 0.83079 to 0.83123, saving model to model/balanced_CV/model_1.h5
# Epoch 16/100
# 215/215 [==============================] - 33s 151ms/step - loss: 0.4029 - accuracy: 0.8233 - auc: 0.8960 - val_loss: 0.3902 - val_accuracy: 0.8325 - val_auc: 0.9029
#
# Epoch 00016: val_accuracy improved from 0.83123 to 0.83250, saving model to model/balanced_CV/model_1.h5
# Epoch 17/100
# 215/215 [==============================] - 29s 136ms/step - loss: 0.4011 - accuracy: 0.8221 - auc: 0.8969 - val_loss: 0.3894 - val_accuracy: 0.8325 - val_auc: 0.9034
#
# Epoch 00017: val_accuracy improved from 0.83250 to 0.83254, saving model to model/balanced_CV/model_1.h5
# Epoch 18/100
# 215/215 [==============================] - 38s 175ms/step - loss: 0.4049 - accuracy: 0.8210 - auc: 0.8946 - val_loss: 0.3886 - val_accuracy: 0.8317 - val_auc: 0.9032
#
# Epoch 00018: val_accuracy did not improve from 0.83254
# Epoch 19/100
# 215/215 [==============================] - 32s 148ms/step - loss: 0.4038 - accuracy: 0.8213 - auc: 0.8956 - val_loss: 0.3894 - val_accuracy: 0.8306 - val_auc: 0.9037
#
# Epoch 00019: val_accuracy did not improve from 0.83254
# Epoch 20/100
# 215/215 [==============================] - 25s 116ms/step - loss: 0.4046 - accuracy: 0.8231 - auc: 0.8951 - val_loss: 0.3881 - val_accuracy: 0.8318 - val_auc: 0.9036
#
# Epoch 00020: val_accuracy did not improve from 0.83254
# Epoch 21/100
# 215/215 [==============================] - 14s 67ms/step - loss: 0.3971 - accuracy: 0.8251 - auc: 0.8993 - val_loss: 0.3877 - val_accuracy: 0.8328 - val_auc: 0.9041
#
# Epoch 00021: val_accuracy improved from 0.83254 to 0.83283, saving model to model/balanced_CV/model_1.h5
# Epoch 22/100
# 215/215 [==============================] - 23s 108ms/step - loss: 0.4041 - accuracy: 0.8210 - auc: 0.8955 - val_loss: 0.3881 - val_accuracy: 0.8323 - val_auc: 0.9045
#
# Epoch 00022: val_accuracy did not improve from 0.83283
# Epoch 23/100
# 215/215 [==============================] - 43s 201ms/step - loss: 0.4022 - accuracy: 0.8232 - auc: 0.8966 - val_loss: 0.3871 - val_accuracy: 0.8335 - val_auc: 0.9043
#
# Epoch 00023: val_accuracy improved from 0.83283 to 0.83352, saving model to model/balanced_CV/model_1.h5
# Epoch 24/100
# 215/215 [==============================] - 43s 200ms/step - loss: 0.4013 - accuracy: 0.8242 - auc: 0.8970 - val_loss: 0.3866 - val_accuracy: 0.8336 - val_auc: 0.9042
#
# Epoch 00024: val_accuracy improved from 0.83352 to 0.83356, saving model to model/balanced_CV/model_1.h5
# Epoch 25/100
# 215/215 [==============================] - 39s 182ms/step - loss: 0.4005 - accuracy: 0.8240 - auc: 0.8972 - val_loss: 0.3874 - val_accuracy: 0.8319 - val_auc: 0.9042
#
# Epoch 00025: val_accuracy did not improve from 0.83356
# Epoch 26/100
# 215/215 [==============================] - 39s 180ms/step - loss: 0.3987 - accuracy: 0.8237 - auc: 0.8982 - val_loss: 0.3861 - val_accuracy: 0.8334 - val_auc: 0.9048
#
# Epoch 00026: val_accuracy did not improve from 0.83356
# Epoch 27/100
# 215/215 [==============================] - 44s 203ms/step - loss: 0.3995 - accuracy: 0.8258 - auc: 0.8976 - val_loss: 0.3847 - val_accuracy: 0.8348 - val_auc: 0.9051
#
# Epoch 00027: val_accuracy improved from 0.83356 to 0.83483, saving model to model/balanced_CV/model_1.h5
# Epoch 28/100
# 215/215 [==============================] - 41s 189ms/step - loss: 0.3977 - accuracy: 0.8248 - auc: 0.8986 - val_loss: 0.3852 - val_accuracy: 0.8346 - val_auc: 0.9059
#
# Epoch 00028: val_accuracy did not improve from 0.83483
# Epoch 29/100
# 215/215 [==============================] - 41s 189ms/step - loss: 0.4021 - accuracy: 0.8231 - auc: 0.8964 - val_loss: 0.3839 - val_accuracy: 0.8326 - val_auc: 0.9055
#
# Epoch 00029: val_accuracy did not improve from 0.83483
# Epoch 30/100
# 215/215 [==============================] - 39s 182ms/step - loss: 0.3960 - accuracy: 0.8254 - auc: 0.8997 - val_loss: 0.3842 - val_accuracy: 0.8345 - val_auc: 0.9055
#
# Epoch 00030: val_accuracy did not improve from 0.83483
# Epoch 31/100
# 215/215 [==============================] - 38s 176ms/step - loss: 0.3956 - accuracy: 0.8256 - auc: 0.9003 - val_loss: 0.3855 - val_accuracy: 0.8328 - val_auc: 0.9053
#
# Epoch 00031: val_accuracy did not improve from 0.83483
# Epoch 32/100
# 215/215 [==============================] - 36s 168ms/step - loss: 0.3978 - accuracy: 0.8252 - auc: 0.8989 - val_loss: 0.3834 - val_accuracy: 0.8354 - val_auc: 0.9058
#
# Epoch 00032: val_accuracy improved from 0.83483 to 0.83545, saving model to model/balanced_CV/model_1.h5
# Epoch 33/100
# 215/215 [==============================] - 38s 179ms/step - loss: 0.3971 - accuracy: 0.8260 - auc: 0.8994 - val_loss: 0.3835 - val_accuracy: 0.8340 - val_auc: 0.9058
#
# Epoch 00033: val_accuracy did not improve from 0.83545
# Epoch 34/100
# 215/215 [==============================] - 33s 152ms/step - loss: 0.3947 - accuracy: 0.8268 - auc: 0.9003 - val_loss: 0.3854 - val_accuracy: 0.8322 - val_auc: 0.9061
#
# Epoch 00034: val_accuracy did not improve from 0.83545
# Epoch 35/100
# 215/215 [==============================] - 35s 165ms/step - loss: 0.3998 - accuracy: 0.8241 - auc: 0.8977 - val_loss: 0.3818 - val_accuracy: 0.8357 - val_auc: 0.9064
#
# Epoch 00035: val_accuracy improved from 0.83545 to 0.83567, saving model to model/balanced_CV/model_1.h5
# Epoch 36/100
# 215/215 [==============================] - 35s 162ms/step - loss: 0.3988 - accuracy: 0.8250 - auc: 0.8984 - val_loss: 0.3826 - val_accuracy: 0.8350 - val_auc: 0.9064
#
# Epoch 00036: val_accuracy did not improve from 0.83567
# Epoch 37/100
# 215/215 [==============================] - 46s 215ms/step - loss: 0.3948 - accuracy: 0.8265 - auc: 0.9005 - val_loss: 0.3825 - val_accuracy: 0.8355 - val_auc: 0.9061
#
# Epoch 00037: val_accuracy did not improve from 0.83567
# Epoch 38/100
# 215/215 [==============================] - 38s 177ms/step - loss: 0.3945 - accuracy: 0.8267 - auc: 0.9006 - val_loss: 0.3827 - val_accuracy: 0.8337 - val_auc: 0.9063
#
# Epoch 00038: val_accuracy did not improve from 0.83567
# Epoch 39/100
# 215/215 [==============================] - 42s 194ms/step - loss: 0.3938 - accuracy: 0.8264 - auc: 0.9007 - val_loss: 0.3811 - val_accuracy: 0.8360 - val_auc: 0.9068
#
# Epoch 00039: val_accuracy improved from 0.83567 to 0.83603, saving model to model/balanced_CV/model_1.h5
# Epoch 40/100
# 215/215 [==============================] - 35s 165ms/step - loss: 0.3933 - accuracy: 0.8281 - auc: 0.9012 - val_loss: 0.3822 - val_accuracy: 0.8366 - val_auc: 0.9074
#
# Epoch 00040: val_accuracy improved from 0.83603 to 0.83658, saving model to model/balanced_CV/model_1.h5
# Epoch 41/100
# 215/215 [==============================] - 32s 150ms/step - loss: 0.3945 - accuracy: 0.8282 - auc: 0.9009 - val_loss: 0.3840 - val_accuracy: 0.8338 - val_auc: 0.9070
#
# Epoch 00041: val_accuracy did not improve from 0.83658
# Epoch 42/100
# 215/215 [==============================] - 28s 130ms/step - loss: 0.3978 - accuracy: 0.8252 - auc: 0.8992 - val_loss: 0.3810 - val_accuracy: 0.8358 - val_auc: 0.9070
#
# Epoch 00042: val_accuracy did not improve from 0.83658
# Epoch 43/100
# 215/215 [==============================] - 31s 142ms/step - loss: 0.3937 - accuracy: 0.8272 - auc: 0.9009 - val_loss: 0.3814 - val_accuracy: 0.8361 - val_auc: 0.9067
#
# Epoch 00043: val_accuracy did not improve from 0.83658
# Epoch 44/100
# 215/215 [==============================] - 30s 140ms/step - loss: 0.3942 - accuracy: 0.8285 - auc: 0.9007 - val_loss: 0.3803 - val_accuracy: 0.8350 - val_auc: 0.9072
#
# Epoch 00044: val_accuracy did not improve from 0.83658
# Epoch 45/100
# 215/215 [==============================] - 33s 155ms/step - loss: 0.3939 - accuracy: 0.8279 - auc: 0.9010 - val_loss: 0.3798 - val_accuracy: 0.8352 - val_auc: 0.9074
#
# Epoch 00045: val_accuracy did not improve from 0.83658
# Epoch 00045: early stopping
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# peptide (InputLayer)            [(None, 30, 20)]     0
# __________________________________________________________________________________________________
# mhc (InputLayer)                [(None, 34, 20)]     0
# __________________________________________________________________________________________________
# conv1_pep (Conv1D)              (None, 30, 128)      7808        peptide[0][0]
# __________________________________________________________________________________________________
# conv1_mhc (Conv1D)              (None, 34, 128)      7808        mhc[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_8 (MaxPooling1D)  (None, 15, 128)      0           conv1_pep[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_9 (MaxPooling1D)  (None, 17, 128)      0           conv1_mhc[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 15, 128)      0           max_pooling1d_8[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 17, 128)      0           max_pooling1d_9[0][0]
# __________________________________________________________________________________________________
# flatten_8 (Flatten)             (None, 1920)         0           dropout_16[0][0]
# __________________________________________________________________________________________________
# flatten_9 (Flatten)             (None, 2176)         0           dropout_18[0][0]
# __________________________________________________________________________________________________
# attention_8 (Attention)         (None, 143)          33281       dropout_16[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 1920)         0           flatten_8[0][0]
# __________________________________________________________________________________________________
# attention_9 (Attention)         (None, 145)          33281       dropout_18[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 2176)         0           flatten_9[0][0]
# __________________________________________________________________________________________________
# attention_flatten_8 (attention_ (None, 128)          0           attention_8[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 1)            1921        dropout_17[0][0]
# __________________________________________________________________________________________________
# attention_flatten_9 (attention_ (None, 128)          0           attention_9[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 1)            2177        dropout_19[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 129)          0           attention_flatten_8[0][0]
#                                                                  dense_20[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 129)          0           attention_flatten_9[0][0]
#                                                                  dense_22[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 1)            130         concatenate_12[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 1)            130         concatenate_13[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 2)            0           dense_21[0][0]
#                                                                  dense_23[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 1)            3           concatenate_14[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 1)            0           dense_24[0][0]
# ==================================================================================================
# Total params: 86,539
# Trainable params: 86,539
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/100
# 215/215 [==============================] - 41s 176ms/step - loss: 0.5799 - accuracy: 0.6940 - auc: 0.7609 - val_loss: 0.4645 - val_accuracy: 0.7849 - val_auc: 0.8625
#
# Epoch 00001: val_accuracy improved from -inf to 0.78494, saving model to model/balanced_CV/model_2.h5
# Epoch 2/100
# 215/215 [==============================] - 31s 142ms/step - loss: 0.4693 - accuracy: 0.7800 - auc: 0.8555 - val_loss: 0.4314 - val_accuracy: 0.8092 - val_auc: 0.8811
#
# Epoch 00002: val_accuracy improved from 0.78494 to 0.80923, saving model to model/balanced_CV/model_2.h5
# Epoch 3/100
# 215/215 [==============================] - 32s 151ms/step - loss: 0.4453 - accuracy: 0.7971 - auc: 0.8712 - val_loss: 0.4178 - val_accuracy: 0.8151 - val_auc: 0.8885
#
# Epoch 00003: val_accuracy improved from 0.80923 to 0.81512, saving model to model/balanced_CV/model_2.h5
# Epoch 4/100
# 215/215 [==============================] - 15s 72ms/step - loss: 0.4377 - accuracy: 0.8015 - auc: 0.8763 - val_loss: 0.4094 - val_accuracy: 0.8201 - val_auc: 0.8931
#
# Epoch 00004: val_accuracy improved from 0.81512 to 0.82007, saving model to model/balanced_CV/model_2.h5
# Epoch 5/100
# 215/215 [==============================] - 14s 63ms/step - loss: 0.4263 - accuracy: 0.8084 - auc: 0.8829 - val_loss: 0.4069 - val_accuracy: 0.8226 - val_auc: 0.8958
#
# Epoch 00005: val_accuracy improved from 0.82007 to 0.82261, saving model to model/balanced_CV/model_2.h5
# Epoch 6/100
# 215/215 [==============================] - 14s 64ms/step - loss: 0.4225 - accuracy: 0.8121 - auc: 0.8849 - val_loss: 0.4010 - val_accuracy: 0.8243 - val_auc: 0.8976
#
# Epoch 00006: val_accuracy improved from 0.82261 to 0.82428, saving model to model/balanced_CV/model_2.h5
# Epoch 7/100
# 215/215 [==============================] - 28s 130ms/step - loss: 0.4203 - accuracy: 0.8145 - auc: 0.8861 - val_loss: 0.4043 - val_accuracy: 0.8226 - val_auc: 0.8988
#
# Epoch 00007: val_accuracy did not improve from 0.82428
# Epoch 8/100
# 215/215 [==============================] - 27s 128ms/step - loss: 0.4191 - accuracy: 0.8142 - auc: 0.8871 - val_loss: 0.3969 - val_accuracy: 0.8267 - val_auc: 0.8999
#
# Epoch 00008: val_accuracy improved from 0.82428 to 0.82668, saving model to model/balanced_CV/model_2.h5
# Epoch 9/100
# 215/215 [==============================] - 34s 160ms/step - loss: 0.4168 - accuracy: 0.8157 - auc: 0.8883 - val_loss: 0.3955 - val_accuracy: 0.8264 - val_auc: 0.9014
#
# Epoch 00009: val_accuracy did not improve from 0.82668
# Epoch 10/100
# 215/215 [==============================] - 39s 183ms/step - loss: 0.4127 - accuracy: 0.8172 - auc: 0.8907 - val_loss: 0.3950 - val_accuracy: 0.8277 - val_auc: 0.9014
#
# Epoch 00010: val_accuracy improved from 0.82668 to 0.82770, saving model to model/balanced_CV/model_2.h5
# Epoch 11/100
# 215/215 [==============================] - 33s 154ms/step - loss: 0.4142 - accuracy: 0.8179 - auc: 0.8898 - val_loss: 0.3916 - val_accuracy: 0.8309 - val_auc: 0.9029
#
# Epoch 00011: val_accuracy improved from 0.82770 to 0.83094, saving model to model/balanced_CV/model_2.h5
# Epoch 12/100
# 215/215 [==============================] - 36s 167ms/step - loss: 0.4104 - accuracy: 0.8177 - auc: 0.8917 - val_loss: 0.3903 - val_accuracy: 0.8308 - val_auc: 0.9035
#
# Epoch 00012: val_accuracy did not improve from 0.83094
# Epoch 13/100
# 215/215 [==============================] - 20s 94ms/step - loss: 0.4094 - accuracy: 0.8191 - auc: 0.8922 - val_loss: 0.3899 - val_accuracy: 0.8308 - val_auc: 0.9038
#
# Epoch 00013: val_accuracy did not improve from 0.83094
# Epoch 14/100
# 215/215 [==============================] - 20s 95ms/step - loss: 0.4089 - accuracy: 0.8202 - auc: 0.8926 - val_loss: 0.3886 - val_accuracy: 0.8310 - val_auc: 0.9040
#
# Epoch 00014: val_accuracy improved from 0.83094 to 0.83098, saving model to model/balanced_CV/model_2.h5
# Epoch 15/100
# 215/215 [==============================] - 15s 70ms/step - loss: 0.4046 - accuracy: 0.8206 - auc: 0.8944 - val_loss: 0.3907 - val_accuracy: 0.8299 - val_auc: 0.9048
#
# Epoch 00015: val_accuracy did not improve from 0.83098
# Epoch 16/100
# 215/215 [==============================] - 13s 60ms/step - loss: 0.4043 - accuracy: 0.8217 - auc: 0.8955 - val_loss: 0.3869 - val_accuracy: 0.8321 - val_auc: 0.9054
#
# Epoch 00016: val_accuracy improved from 0.83098 to 0.83214, saving model to model/balanced_CV/model_2.h5
# Epoch 17/100
# 215/215 [==============================] - 13s 60ms/step - loss: 0.4033 - accuracy: 0.8234 - auc: 0.8957 - val_loss: 0.3861 - val_accuracy: 0.8330 - val_auc: 0.9056
#
# ...
# Epoch 33/100
# 215/215 [==============================] - 11s 50ms/step - loss: 0.4005 - accuracy: 0.8232 - auc: 0.8973 - val_loss: 0.3804 - val_accuracy: 0.8355 - val_auc: 0.9081
#
# Epoch 00033: val_accuracy did not improve from 0.83570
# Epoch 34/100
# 215/215 [==============================] - 11s 51ms/step - loss: 0.3979 - accuracy: 0.8242 - auc: 0.8988 - val_loss: 0.3802 - val_accuracy: 0.8363 - val_auc: 0.9084
#
# Epoch 00034: val_accuracy improved from 0.83570 to 0.83632, saving model to model/balanced_CV/model_3.h5
# Epoch 35/100
# 215/215 [==============================] - 12s 55ms/step - loss: 0.3984 - accuracy: 0.8244 - auc: 0.8985 - val_loss: 0.3806 - val_accuracy: 0.8361 - val_auc: 0.9078
#
# Epoch 00035: val_accuracy did not improve from 0.83632
# Epoch 36/100
# 215/215 [==============================] - 11s 50ms/step - loss: 0.3964 - accuracy: 0.8263 - auc: 0.8998 - val_loss: 0.3790 - val_accuracy: 0.8354 - val_auc: 0.9083
#
# Epoch 00036: val_accuracy did not improve from 0.83632
# Epoch 37/100
# 215/215 [==============================] - 14s 67ms/step - loss: 0.3960 - accuracy: 0.8265 - auc: 0.8997 - val_loss: 0.3803 - val_accuracy: 0.8352 - val_auc: 0.9082
#
# Epoch 00037: val_accuracy did not improve from 0.83632
# Epoch 38/100
# 215/215 [==============================] - 30s 137ms/step - loss: 0.3984 - accuracy: 0.8220 - auc: 0.8987 - val_loss: 0.3795 - val_accuracy: 0.8359 - val_auc: 0.9088
#
# Epoch 00038: val_accuracy did not improve from 0.83632
# Epoch 39/100
# 215/215 [==============================] - 25s 116ms/step - loss: 0.3978 - accuracy: 0.8252 - auc: 0.8990 - val_loss: 0.3787 - val_accuracy: 0.8361 - val_auc: 0.9089
#
# Epoch 00039: val_accuracy did not improve from 0.83632
# Epoch 00039: early stopping
# Model: "model_8"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# peptide (InputLayer)            [(None, 30, 20)]     0
# __________________________________________________________________________________________________
# mhc (InputLayer)                [(None, 34, 20)]     0
# __________________________________________________________________________________________________
# conv1_pep (Conv1D)              (None, 30, 128)      7808        peptide[0][0]
# __________________________________________________________________________________________________
# conv1_mhc (Conv1D)              (None, 34, 128)      7808        mhc[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_16 (MaxPooling1D) (None, 15, 128)      0           conv1_pep[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_17 (MaxPooling1D) (None, 17, 128)      0           conv1_mhc[0][0]
# __________________________________________________________________________________________________
# dropout_32 (Dropout)            (None, 15, 128)      0           max_pooling1d_16[0][0]
# __________________________________________________________________________________________________
# dropout_34 (Dropout)            (None, 17, 128)      0           max_pooling1d_17[0][0]
# __________________________________________________________________________________________________
# flatten_16 (Flatten)            (None, 1920)         0           dropout_32[0][0]
# __________________________________________________________________________________________________
# flatten_17 (Flatten)            (None, 2176)         0           dropout_34[0][0]
# __________________________________________________________________________________________________
# attention_16 (Attention)        (None, 143)          33281       dropout_32[0][0]
# __________________________________________________________________________________________________
# dropout_33 (Dropout)            (None, 1920)         0           flatten_16[0][0]
# __________________________________________________________________________________________________
# attention_17 (Attention)        (None, 145)          33281       dropout_34[0][0]
# __________________________________________________________________________________________________
# dropout_35 (Dropout)            (None, 2176)         0           flatten_17[0][0]
# __________________________________________________________________________________________________
# attention_flatten_16 (attention (None, 128)          0           attention_16[0][0]
# __________________________________________________________________________________________________
# dense_40 (Dense)                (None, 1)            1921        dropout_33[0][0]
# __________________________________________________________________________________________________
# attention_flatten_17 (attention (None, 128)          0           attention_17[0][0]
# __________________________________________________________________________________________________
# dense_42 (Dense)                (None, 1)            2177        dropout_35[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 129)          0           attention_flatten_16[0][0]
#                                                                  dense_40[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 129)          0           attention_flatten_17[0][0]
#                                                                  dense_42[0][0]
# __________________________________________________________________________________________________
# dense_41 (Dense)                (None, 1)            130         concatenate_24[0][0]
# __________________________________________________________________________________________________
# dense_43 (Dense)                (None, 1)            130         concatenate_25[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 2)            0           dense_41[0][0]
#                                                                  dense_43[0][0]
# __________________________________________________________________________________________________
# dense_44 (Dense)                (None, 1)            3           concatenate_26[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 1)            0           dense_44[0][0]
# ==================================================================================================
# Total params: 86,539
# Trainable params: 86,539
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/100
# 215/215 [==============================] - 25s 98ms/step - loss: 0.5811 - accuracy: 0.6882 - auc: 0.7561 - val_loss: 0.4655 - val_accuracy: 0.7823 - val_auc: 0.8592
#
# Epoch 00001: val_accuracy improved from -inf to 0.78231, saving model to model/balanced_CV/model_4.h5
# Epoch 2/100
# 215/215 [==============================] - 26s 123ms/step - loss: 0.4703 - accuracy: 0.7803 - auc: 0.8550 - val_loss: 0.4332 - val_accuracy: 0.8030 - val_auc: 0.8788
#
# Epoch 00002: val_accuracy improved from 0.78231 to 0.80304, saving model to model/balanced_CV/model_4.h5
# Epoch 3/100
# 215/215 [==============================] - 12s 58ms/step - loss: 0.4437 - accuracy: 0.7974 - auc: 0.8716 - val_loss: 0.4196 - val_accuracy: 0.8129 - val_auc: 0.8865
#
# Epoch 00003: val_accuracy improved from 0.80304 to 0.81293, saving model to model/balanced_CV/model_4.h5
# Epoch 4/100
# 215/215 [==============================] - 11s 51ms/step - loss: 0.4302 - accuracy: 0.8057 - auc: 0.8801 - val_loss: 0.4126 - val_accuracy: 0.8171 - val_auc: 0.8907
#
# Epoch 00004: val_accuracy improved from 0.81293 to 0.81708, saving model to model/balanced_CV/model_4.h5
# Epoch 5/100
# 215/215 [==============================] - 13s 60ms/step - loss: 0.4265 - accuracy: 0.8093 - auc: 0.8828 - val_loss: 0.4104 - val_accuracy: 0.8158 - val_auc: 0.8924
#
# Epoch 00005: val_accuracy did not improve from 0.81708
# Epoch 6/100
# 215/215 [==============================] - 20s 93ms/step - loss: 0.4211 - accuracy: 0.8114 - auc: 0.8860 - val_loss: 0.4048 - val_accuracy: 0.8198 - val_auc: 0.8946
#
# Epoch 00006: val_accuracy improved from 0.81708 to 0.81981, saving model to model/balanced_CV/model_4.h5
# Epoch 7/100
# 215/215 [==============================] - 18s 85ms/step - loss: 0.4168 - accuracy: 0.8154 - auc: 0.8881 - val_loss: 0.4053 - val_accuracy: 0.8193 - val_auc: 0.8959
#
# Epoch 00007: val_accuracy did not improve from 0.81981
# Epoch 8/100
# 215/215 [==============================] - 18s 82ms/step - loss: 0.4172 - accuracy: 0.8136 - auc: 0.8879 - val_loss: 0.3990 - val_accuracy: 0.8223 - val_auc: 0.8973
#
# Epoch 00008: val_accuracy improved from 0.81981 to 0.82228, saving model to model/balanced_CV/model_4.h5
# Epoch 9/100
# 215/215 [==============================] - 25s 118ms/step - loss: 0.4151 - accuracy: 0.8165 - auc: 0.8893 - val_loss: 0.3981 - val_accuracy: 0.8238 - val_auc: 0.8979
#
# Epoch 00009: val_accuracy improved from 0.82228 to 0.82381, saving model to model/balanced_CV/model_4.h5
# Epoch 10/100
# 215/215 [==============================] - 25s 118ms/step - loss: 0.4131 - accuracy: 0.8178 - auc: 0.8900 - val_loss: 0.4024 - val_accuracy: 0.8210 - val_auc: 0.8980
#
# Epoch 00010: val_accuracy did not improve from 0.82381
# Epoch 11/100
# 215/215 [==============================] - 24s 112ms/step - loss: 0.4068 - accuracy: 0.8203 - auc: 0.8942 - val_loss: 0.3962 - val_accuracy: 0.8245 - val_auc: 0.8995
#
# Epoch 00011: val_accuracy improved from 0.82381 to 0.82450, saving model to model/balanced_CV/model_4.h5
# Epoch 12/100
# 215/215 [==============================] - 29s 135ms/step - loss: 0.4066 - accuracy: 0.8213 - auc: 0.8939 - val_loss: 0.3968 - val_accuracy: 0.8243 - val_auc: 0.8992
#
# Epoch 00012: val_accuracy did not improve from 0.82450
# Epoch 13/100
# 215/215 [==============================] - 35s 161ms/step - loss: 0.4054 - accuracy: 0.8211 - auc: 0.8945 - val_loss: 0.3944 - val_accuracy: 0.8268 - val_auc: 0.8997
#
# Epoch 00013: val_accuracy improved from 0.82450 to 0.82675, saving model to model/balanced_CV/model_4.h5
# Epoch 14/100
# 215/215 [==============================] - 20s 91ms/step - loss: 0.4059 - accuracy: 0.8208 - auc: 0.8944 - val_loss: 0.3933 - val_accuracy: 0.8259 - val_auc: 0.9007
#
# Epoch 00014: val_accuracy did not improve from 0.82675
# Epoch 15/100
# 215/215 [==============================] - 11s 54ms/step - loss: 0.4044 - accuracy: 0.8223 - auc: 0.8957 - val_loss: 0.3931 - val_accuracy: 0.8272 - val_auc: 0.9011
#
# Epoch 00015: val_accuracy improved from 0.82675 to 0.82719, saving model to model/balanced_CV/model_4.h5
# Epoch 16/100
# 215/215 [==============================] - 11s 51ms/step - loss: 0.4032 - accuracy: 0.8226 - auc: 0.8962 - val_loss: 0.3917 - val_accuracy: 0.8281 - val_auc: 0.9015
#
# Epoch 00016: val_accuracy improved from 0.82719 to 0.82810, saving model to model/balanced_CV/model_4.h5
# Epoch 17/100
# 215/215 [==============================] - 11s 50ms/step - loss: 0.4010 - accuracy: 0.8238 - auc: 0.8973 - val_loss: 0.3911 - val_accuracy: 0.8281 - val_auc: 0.9018
#
# Epoch 00017: val_accuracy did not improve from 0.82810
# Epoch 18/100
# 215/215 [==============================] - 11s 52ms/step - loss: 0.4031 - accuracy: 0.8235 - auc: 0.8959 - val_loss: 0.3909 - val_accuracy: 0.8266 - val_auc: 0.9021
#
# Epoch 00018: val_accuracy did not improve from 0.82810
# Epoch 19/100
# 215/215 [==============================] - 12s 58ms/step - loss: 0.4011 - accuracy: 0.8239 - auc: 0.8971 - val_loss: 0.3905 - val_accuracy: 0.8275 - val_auc: 0.9022
#
# Epoch 00019: val_accuracy did not improve from 0.82810
# Epoch 20/100
# 215/215 [==============================] - 13s 61ms/step - loss: 0.4025 - accuracy: 0.8232 - auc: 0.8960 - val_loss: 0.3911 - val_accuracy: 0.8270 - val_auc: 0.9025
#
# Epoch 00020: val_accuracy did not improve from 0.82810
# Epoch 21/100
# 215/215 [==============================] - 22s 103ms/step - loss: 0.3982 - accuracy: 0.8244 - auc: 0.8990 - val_loss: 0.3882 - val_accuracy: 0.8296 - val_auc: 0.9030
#
# Epoch 00021: val_accuracy improved from 0.82810 to 0.82955, saving model to model/balanced_CV/model_4.h5
# Epoch 22/100
# 215/215 [==============================] - 35s 165ms/step - loss: 0.3980 - accuracy: 0.8238 - auc: 0.8990 - val_loss: 0.3883 - val_accuracy: 0.8286 - val_auc: 0.9028
#
# Epoch 00022: val_accuracy did not improve from 0.82955
# Epoch 23/100
# 215/215 [==============================] - 34s 157ms/step - loss: 0.3994 - accuracy: 0.8238 - auc: 0.8980 - val_loss: 0.3872 - val_accuracy: 0.8296 - val_auc: 0.9036
#
# Epoch 00023: val_accuracy improved from 0.82955 to 0.82959, saving model to model/balanced_CV/model_4.h5
# Epoch 24/100
# 215/215 [==============================] - 38s 178ms/step - loss: 0.4014 - accuracy: 0.8228 - auc: 0.8970 - val_loss: 0.3874 - val_accuracy: 0.8303 - val_auc: 0.9030
#
# Epoch 00024: val_accuracy improved from 0.82959 to 0.83028, saving model to model/balanced_CV/model_4.h5
# Epoch 25/100
# 215/215 [==============================] - 40s 184ms/step - loss: 0.3992 - accuracy: 0.8240 - auc: 0.8983 - val_loss: 0.3880 - val_accuracy: 0.8280 - val_auc: 0.9036
#
# Epoch 00025: val_accuracy did not improve from 0.83028
# Epoch 26/100
# 215/215 [==============================] - 22s 104ms/step - loss: 0.3948 - accuracy: 0.8265 - auc: 0.9007 - val_loss: 0.3880 - val_accuracy: 0.8294 - val_auc: 0.9032
#
# Epoch 00026: val_accuracy did not improve from 0.83028
# Epoch 27/100
# 215/215 [==============================] - 20s 94ms/step - loss: 0.3981 - accuracy: 0.8249 - auc: 0.8987 - val_loss: 0.3868 - val_accuracy: 0.8290 - val_auc: 0.9039
#
# Epoch 00027: val_accuracy did not improve from 0.83028
# Epoch 28/100
# 215/215 [==============================] - 16s 75ms/step - loss: 0.3954 - accuracy: 0.8265 - auc: 0.8997 - val_loss: 0.3860 - val_accuracy: 0.8313 - val_auc: 0.9042
#
# Epoch 00028: val_accuracy improved from 0.83028 to 0.83126, saving model to model/balanced_CV/model_4.h5
# Epoch 29/100
# 215/215 [==============================] - 14s 63ms/step - loss: 0.3936 - accuracy: 0.8279 - auc: 0.9009 - val_loss: 0.3853 - val_accuracy: 0.8306 - val_auc: 0.9050
#
# Epoch 00029: val_accuracy did not improve from 0.83126
# Epoch 30/100
# 215/215 [==============================] - 28s 128ms/step - loss: 0.3965 - accuracy: 0.8246 - auc: 0.8995 - val_loss: 0.3856 - val_accuracy: 0.8306 - val_auc: 0.9043
#
# Epoch 00030: val_accuracy did not improve from 0.83126
# Epoch 31/100
# 215/215 [==============================] - 28s 129ms/step - loss: 0.3931 - accuracy: 0.8267 - auc: 0.9014 - val_loss: 0.3850 - val_accuracy: 0.8306 - val_auc: 0.9051
#
# Epoch 00031: val_accuracy did not improve from 0.83126
# Epoch 32/100
# 215/215 [==============================] - 34s 156ms/step - loss: 0.3940 - accuracy: 0.8263 - auc: 0.9007 - val_loss: 0.3851 - val_accuracy: 0.8301 - val_auc: 0.9051
#
# Epoch 00032: val_accuracy did not improve from 0.83126
# Epoch 33/100
# 215/215 [==============================] - 33s 154ms/step - loss: 0.3925 - accuracy: 0.8268 - auc: 0.9013 - val_loss: 0.3876 - val_accuracy: 0.8294 - val_auc: 0.9053
#
# Epoch 00033: val_accuracy did not improve from 0.83126
# Epoch 00033: early stopping

# %%
font1 = {'family' : 'Times New Roman',
        'weight' : 'normal',
        'size'   : 16}
figsize=6.2, 6.2

for i, (train, test) in enumerate(kfold.split(train_pep, train_target)):
    training_pep = train_pep[train]
    training_mhc = train_mhc[train]
    training_target = train_target[train]
    
    validation_pep = train_pep[test]
    validation_mhc = train_mhc[test]
    validation_target = train_target[test]

    if i == 0:
        saved_model = build_model(training_pep, training_mhc)
        saved_model.load_weights('model/balanced_CV/model_' +str(i)+'.h5')
        probas_ = saved_model.predict([np.array(validation_pep),np.array(validation_mhc)])
        allprobas_ = np.append(allprobas_, probas_)           
        all_labels = np.append(all_labels, validation_target)
        del saved_model

        fpr, tpr, thresholds = roc_curve(all_labels, allprobas_)
        roc_auc = auc(fpr, tpr)
        precision, recall, _ = precision_recall_curve(all_labels, allprobas_)
        aupr = average_precision_score(all_labels, allprobas_)
        print(roc_auc)
        print(aupr)

        figure1, ax1 = plt.subplots(figsize=figsize)
        ax1.tick_params(labelsize=18)
        labels = ax1.get_xticklabels() + ax1.get_yticklabels()
        [label.set_fontname('Times New Roman') for label in labels]  
        ax1.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
        label='Luck', alpha=.8)

        ax1.plot(fpr, tpr, color='b',
                label=r'First CV ROC (AUC = %0.4f)' % (roc_auc),
                    lw=2, alpha=.8)
        ax1.set_xlim([-0.05, 1.05])
        ax1.set_ylim([-0.05, 1.05])
        ax1.set_xlabel('False Positive Rate', font1)
        ax1.set_ylabel('True Positive Rate', font1)
        title1 = 'Cross Validated ROC Curve'
        ax1.set_title(title1, font1)
        ax1.legend(loc="lower right")
        
        ########PR_figure
        figure2, ax2 = plt.subplots(figsize=figsize)
        ax2.tick_params(labelsize=18)
        labels = ax2.get_xticklabels() + ax2.get_yticklabels()
        [label.set_fontname('Times New Roman') for label in labels] 

        ax2.plot(recall, precision, color='b',
                label=r'First CV Precision-Recall (AUC = %0.4f)' % aupr,
                lw=2, alpha=.8)

        ax2.set_xlim([-0.05, 1.05])
        ax2.set_ylim([-0.05, 1.05])
        ax2.set_xlabel('Recall', font1)
        ax2.set_ylabel('Precision', font1)
        title2 = 'Cross Validated PR Curve'
        ax2.set_title(title2, font1)
        ax2.legend(loc="lower left")

    else:
        saved_model = build_model(training_pep, training_mhc)
        saved_model.load_weights('model/balanced_CV/model_' +str(i)+'.h5')
        probas_ = saved_model.predict([np.array(validation_pep),np.array(validation_mhc)])
        allprobas_ = np.append(allprobas_, probas_)           
        all_labels = np.append(all_labels, validation_target)
        del saved_model
        
        fpr, tpr, thresholds = roc_curve(validation_target, probas_)
        roc_auc = auc(fpr, tpr)
        precision, recall, _ = precision_recall_curve(validation_target, probas_)
        aupr = average_precision_score(validation_target, probas_)
        print(roc_auc)
        print(aupr)

        ax1.plot(fpr, tpr,
        label=str(i)+'th CV ROC (AUC = %0.4f)' % (roc_auc),
            lw=2, alpha=.8)
        ax1.legend(loc="lower right")


        ax2.plot(recall, precision, 
        label=str(i)+'th CV Precision-Recall (AUC = %0.4f)' % (aupr),
        lw=2, alpha=.8)
        ax2.legend(loc="lower left")
# Out:
# 0.9076184015038307
# 0.8885606467788287
# 0.9074052671599256
# 0.8880466291554048
# 0.9112082280364191
# 0.8964554561727821
# 0.9083762468675407
# 0.8907209478441537
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# 0.9042512502750748
# 0.8825800807085958

# %%
figure1.savefig('figures/balancedCV_5_fold_roc.jpg', dpi=300, bbox_inches = 'tight')
figure2.savefig('figures/balancedCV_5_fold_prc.jpg', dpi=300, bbox_inches = 'tight')

# %%
font1 = {'family' : 'Times New Roman',
        'weight' : 'normal',
        'size'   : 16}
figsize=6.2, 6.2

########ROC_figure
figure1, ax1 = plt.subplots(figsize=figsize)
ax1.tick_params(labelsize=18)
labels = ax1.get_xticklabels() + ax1.get_yticklabels()
[label.set_fontname('Times New Roman') for label in labels]  

fpr, tpr, thresholds = roc_curve(all_labels, allprobas_)
roc_auc = auc(fpr, tpr)
print(roc_auc)

ax1.plot(fpr, tpr, color='b',
    label=r'Mean ROC (AUC = %0.4f)' % (roc_auc),
    lw=2, alpha=.8)
ax1.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
        label='Luck', alpha=.8)
ax1.set_xlim([-0.05, 1.05])
ax1.set_ylim([-0.05, 1.05])
ax1.set_xlabel('False Positive Rate', font1)
ax1.set_ylabel('True Positive Rate', font1)
title1 = 'Cross Validated ROC Curve'
ax1.set_title(title1, font1)
ax1.legend(loc="lower right")
figure1.savefig('figures/balancedCV_mean_5_fold_roc.jpg', dpi=300, bbox_inches = 'tight')

########PR_figure
figure2, ax2 = plt.subplots(figsize=figsize)
ax2.tick_params(labelsize=18)
labels = ax2.get_xticklabels() + ax2.get_yticklabels()
[label.set_fontname('Times New Roman') for label in labels] 

precision, recall, _ = precision_recall_curve(all_labels, allprobas_)
ax2.plot(recall, precision, color='b',
        label=r'Mean Precision-Recall (AUC = %0.4f)' % (average_precision_score(all_labels, allprobas_)),
        lw=2, alpha=.8)

ax2.set_xlim([-0.05, 1.05])
ax2.set_ylim([-0.05, 1.05])
ax2.set_xlabel('Recall', font1)
ax2.set_ylabel('Precision', font1)
title2 = 'Cross Validated PR Curve'
ax2.set_title(title2, font1)
ax2.legend(loc="lower left")
figure2.savefig('figures/balancedCV_mean_5_fold_pr.jpg', dpi=300, bbox_inches = 'tight')
# Out:
# 0.9075522117012853

# %%
allprobas2_=np.array([]) 
all_labels2=np.array([])

# %%
font1 = {'family' : 'Times New Roman',
        'weight' : 'normal',
        'size'   : 16}
figsize=6.2, 6.2

for i in range(5):
    if i == 0:
        saved_model = build_model(training_pep, training_mhc)
        saved_model.load_weights('model/balanced_CV/model_' +str(i)+'.h5')
        probas_ = saved_model.predict([np.array(test_pep),np.array(test_mhc)])
        allprobas2_ = np.append(allprobas2_, probas_)           
        all_labels2 = np.append(all_labels2, test_target)
        del saved_model

        fpr, tpr, thresholds = roc_curve(all_labels2, allprobas2_)
        roc_auc = auc(fpr, tpr)
        precision, recall, _ = precision_recall_curve(all_labels2, allprobas2_)
        aupr = average_precision_score(all_labels2, allprobas2_)
        print(roc_auc)
        print(aupr)

        figure1, ax1 = plt.subplots(figsize=figsize)
        ax1.tick_params(labelsize=18)
        labels = ax1.get_xticklabels() + ax1.get_yticklabels()
        [label.set_fontname('Times New Roman') for label in labels]  
        ax1.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
        label='Luck', alpha=.8)

        ax1.plot(fpr, tpr, color='b',
                label=r'First CV ROC (AUC = %0.4f)' % (roc_auc),
                    lw=2, alpha=.8)
        ax1.set_xlim([-0.05, 1.05])
        ax1.set_ylim([-0.05, 1.05])
        ax1.set_xlabel('False Positive Rate', font1)
        ax1.set_ylabel('True Positive Rate', font1)
        title1 = 'Cross Validated ROC Curve'
        ax1.set_title(title1, font1)
        ax1.legend(loc="lower right")
        
        ########PR_figure
        figure2, ax2 = plt.subplots(figsize=figsize)
        ax2.tick_params(labelsize=18)
        labels = ax2.get_xticklabels() + ax2.get_yticklabels()
        [label.set_fontname('Times New Roman') for label in labels] 

        ax2.plot(recall, precision, color='b',
                label=r'First CV Precision-Recall (AUC = %0.4f)' % aupr,
                lw=2, alpha=.8)

        ax2.set_xlim([-0.05, 1.05])
        ax2.set_ylim([-0.05, 1.05])
        ax2.set_xlabel('Recall', font1)
        ax2.set_ylabel('Precision', font1)
        title2 = 'Cross Validated PR Curve'
        ax2.set_title(title2, font1)
        ax2.legend(loc="lower left")

    else:
        saved_model = build_model(training_pep, training_mhc)
        saved_model.load_weights('model/balanced_CV/model_' +str(i)+'.h5')
        probas_ = saved_model.predict([np.array(test_pep),np.array(test_mhc)])
        allprobas2_ = np.append(allprobas2_, probas_)           
        all_labels2 = np.append(all_labels2, test_target)
        del saved_model
        
        fpr, tpr, thresholds = roc_curve(test_target, probas_)
        roc_auc = auc(fpr, tpr)
        precision, recall, _ = precision_recall_curve(test_target, probas_)
        aupr = average_precision_score(test_target, probas_)
        print(roc_auc)
        print(aupr)

        ax1.plot(fpr, tpr,
        label=str(i)+'th CV ROC (AUC = %0.4f)' % (roc_auc),
            lw=2, alpha=.8)
        ax1.legend(loc="lower right")


        ax2.plot(recall, precision, 
        label=str(i)+'th CV Precision-Recall (AUC = %0.4f)' % (aupr),
        lw=2, alpha=.8)
        ax2.legend(loc="lower left")

figure1.savefig('figures/balancedCV_test_5_fold_roc.jpg', dpi=300, bbox_inches = 'tight')
figure2.savefig('figures/balancedCV_test_5_fold_prc.jpg', dpi=300, bbox_inches = 'tight')
# Out:
# 0.9068794541958107
# 0.8883133651407235
# 0.9062186480139275
# 0.8877379941334274
# 0.9075363740292681
# 0.8884327309718358
# 0.9047241980901719
# 0.8857800414491854
# 0.9045659021762296
# 0.8848922318135124

# %%
font1 = {'family' : 'Times New Roman',
        'weight' : 'normal',
        'size'   : 16}
figsize=6.2, 6.2

########ROC_figure
figure1, ax1 = plt.subplots(figsize=figsize)
ax1.tick_params(labelsize=18)
labels = ax1.get_xticklabels() + ax1.get_yticklabels()
[label.set_fontname('Times New Roman') for label in labels]  

fpr, tpr, thresholds = roc_curve(all_labels2, allprobas2_)
roc_auc = auc(fpr, tpr)
print(roc_auc)

ax1.plot(fpr, tpr, color='b',
    label=r'Mean ROC (AUC = %0.4f)' % (roc_auc),
    lw=2, alpha=.8)
ax1.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
        label='Luck', alpha=.8)
ax1.set_xlim([-0.05, 1.05])
ax1.set_ylim([-0.05, 1.05])
ax1.set_xlabel('False Positive Rate', font1)
ax1.set_ylabel('True Positive Rate', font1)
title1 = 'Cross Validated ROC Curve'
ax1.set_title(title1, font1)
ax1.legend(loc="lower right")
figure1.savefig('figures/balancedCV_test_mean_5_fold_roc.jpg', dpi=300, bbox_inches = 'tight')

########PR_figure
figure2, ax2 = plt.subplots(figsize=figsize)
ax2.tick_params(labelsize=18)
labels = ax2.get_xticklabels() + ax2.get_yticklabels()
[label.set_fontname('Times New Roman') for label in labels] 

precision, recall, _ = precision_recall_curve(all_labels2, allprobas2_)
ax2.plot(recall, precision, color='b',
        label=r'Mean Precision-Recall (AUC = %0.4f)' % (average_precision_score(all_labels2, allprobas2_)),
        lw=2, alpha=.8)

ax2.set_xlim([-0.05, 1.05])
ax2.set_ylim([-0.05, 1.05])
ax2.set_xlabel('Recall', font1)
ax2.set_ylabel('Precision', font1)
title2 = 'Cross Validated PR Curve'
ax2.set_title(title2, font1)
ax2.legend(loc="lower left")
figure2.savefig('figures/balancedCV_test_mean_5_fold_pr.jpg', dpi=300, bbox_inches = 'tight')
# Out:
# 0.9056613583107997
