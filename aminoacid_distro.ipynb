# %%
import matplotlib.pyplot as plt

# %%
c = [0.0716, 0.0145, 0.0323, 0.0388, 0.0632, 0.0458, 0.0194, 0.0732, 0.0483, 0.127, 0.0384, 0.0366, 0.0416, 0.028, 0.0463, 0.0666, 0.0622, 0.0735, 0.0178, 0.0544]
aa = ['A', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'K', 'L', 'M','N','P','Q','R','S','T','V','W','Y']

# %%
x = plt.bar(aa, c)
plt.rcParams['figure.figsize'] = (10, 20)
plt.xlabel('Amino Acid')
plt.ylabel('Frequency')
plt.title('Amino Acid Distribution in Viral Epitopes')
plt.bar_label(x)
plt.show()
